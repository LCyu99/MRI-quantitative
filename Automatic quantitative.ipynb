# %%
import os
import cv2
import numpy as np

def process_images(images_dir, mask_dir, output_dir):
    # 确保输出目录存在
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # 遍历图像目录中的所有文件
    for filename in os.listdir(images_dir):
        if filename.endswith('.png') or filename.endswith('.jpg'):
            try:
                # 读取原始图像
                image_path = os.path.join(images_dir, filename)
                image = cv2.imread(image_path)

                # 读取对应的mask图像
                mask_filename = os.path.splitext(filename)[0] + '.png'
                mask_path = os.path.join(mask_dir, mask_filename)
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

                if image is None or mask is None:
                    raise Exception(f'Failed to load image or mask: {filename}')

                # 反转mask图像，使得被mask的区域为白色，背景为黑色
                mask = cv2.bitwise_not(mask)

                # 将mask区域保留在原始图像中，其他区域填充为黑色
                result_image = cv2.bitwise_and(image, image, mask=mask)

                # 保存结果图像
                output_path = os.path.join(output_dir, filename)
                cv2.imwrite(output_path, result_image)

            except Exception as e:
                print(f'Error processing {filename}: {e}')


# 使用示例
if __name__ == "__main__":
    images_dir = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\images'
    mask_dir = r'C:\Users\Administrator\Desktop\mode\segement\test\GT\masks\intervertebral disc'
    output_dir = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\IVD-mask'

    process_images(images_dir, mask_dir, output_dir)
# 将mask区域保留在原始图像中，其他区域填充为黑色
# Out:
# Error processing 00201.png: Failed to load image or mask: 00201.png
# Error processing 00202.png: Failed to load image or mask: 00202.png
# Error processing 00203.png: Failed to load image or mask: 00203.png
# Error processing 00502.png: Failed to load image or mask: 00502.png
# Error processing 00887.png: Failed to load image or mask: 00887.png
# Error processing 00888.png: Failed to load image or mask: 00888.png

# %%
import cv2
import numpy as np
import os

def preprocess_image(image):
    # 对图像进行预处理，增强高信号区域与低信号区域的对比度
    # 这里可以根据具体情况选择合适的预处理方法，比如直方图均衡化等
    # 这里简单地使用对比度拉伸
    min_val = np.min(image)
    max_val = np.max(image)
    stretched_image = (image - min_val) / (max_val - min_val) * 255
    return stretched_image.astype(np.uint8)

def extract_fat_tissue_mask(image_dir, output_dir):
    # 遍历图片文件夹下的所有MRI图片
    for image_name in os.listdir(image_dir):
        if image_name.endswith(".png") or image_name.endswith(".jpg"):
            image_path = os.path.join(image_dir, image_name)

            # 读取MRI图片
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # 对图像进行预处理
            preprocessed_image = preprocess_image(image)

            # 使用信号阈值方法提取高信号部分
            _, thresholded_image = cv2.threshold(preprocessed_image, 160, 255, cv2.THRESH_BINARY)

            # 将提取的高信号部分作为mask
            fat_tissue_mask = thresholded_image

            # 保存mask图片
            mask_output_path = os.path.join(output_dir, image_name.split('.')[0] + '.png')
            cv2.imwrite(mask_output_path, fat_tissue_mask)

# 调用函数并传入路径
image_dir = r'C:\Users\Administrator\Desktop\mode\test\out10'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\out11'
extract_fat_tissue_mask(image_dir, output_dir)
  # 使用对比度拉伸增强图像对比度后二值化mask

# %%
import cv2
import numpy as np
import os

def extract_fat_tissue_mask(image_dir, output_dir):
    # 遍历图片文件夹下的所有MRI图片
    for image_name in os.listdir(image_dir):
        if image_name.endswith(".png") or image_name.endswith(".jpg"):
            image_path = os.path.join(image_dir, image_name)

            # 读取MRI图片
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # 使用Otsu二进制阈值
            _, fat_tissue_mask = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

            # 保存mask图片
            mask_output_path = os.path.join(output_dir, image_name.split('.')[0] + '.png')
            cv2.imwrite(mask_output_path, fat_tissue_mask)

# 调用函数并传入路径
image_dir = r'C:\Users\Administrator\Desktop\mode\test\out'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\out'
extract_fat_tissue_mask(image_dir, output_dir)
# 使用Otsu二进制阈值

# %%
import cv2
import numpy as np
import os

def extract_fat_tissue_mask_adaptive(image_dir, output_dir):
    # 遍历图片文件夹下的所有MRI图片
    for image_name in os.listdir(image_dir):
        if image_name.endswith(".png") or image_name.endswith(".jpg"):
            image_path = os.path.join(image_dir, image_name)

            # 读取MRI图片
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # 使用自适应阈值二进制阈值
            fat_tissue_mask = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 1)

            # 保存mask图片
            mask_output_path = os.path.join(output_dir, image_name.split('.')[0] + '.png')
            cv2.imwrite(mask_output_path, fat_tissue_mask)

# 调用函数并传入路径
image_dir = r'C:\Users\Administrator\Desktop\mode\test\out2'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\out8'
extract_fat_tissue_mask_adaptive(image_dir, output_dir)

# %%
import os
import cv2

# 定义目录
images_dir = r'C:\Users\Administrator\Desktop\mode\test\mask5'
mask_dir = r'C:\Users\Administrator\Desktop\mode\test\mask3'

# 计算脂肪浸润率的函数
def calculate_fat_infiltration_ratio(image_path, mask_path):
    # 读取图片
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    # 计算图片中的白色像素数量（假设白色像素值为255）
    white_pixels_image = cv2.countNonZero(image)

    # 计算掩模中的黑色像素数量（假设黑色像素值为0）
    black_pixels_mask = cv2.countNonZero(cv2.bitwise_not(mask))

    # 计算脂肪浸润率
    fat_infiltration_ratio = white_pixels_image / black_pixels_mask

    return fat_infiltration_ratio

# 遍历图片及其对应的掩模
fat_infiltration_ratios = []
for image_file in os.listdir(images_dir):
    if image_file.endswith('.jpg') or image_file.endswith('.png'):
        image_path = os.path.join(images_dir, image_file)
        mask_file = image_file.replace('.jpg', '.jpg').replace('.png', '.png')
        mask_path = os.path.join(mask_dir, mask_file)
        if os.path.exists(mask_path):
            fat_infiltration_ratio = calculate_fat_infiltration_ratio(image_path, mask_path)
            fat_infiltration_ratios.append(fat_infiltration_ratio)
            print(f"{image_file} 的脂肪浸润率为：{fat_infiltration_ratio}")

# 计算平均脂肪浸润率
if fat_infiltration_ratios:
    average_fat_infiltration_ratio = sum(fat_infiltration_ratios) / len(fat_infiltration_ratios)
    print(f"平均脂肪浸润率为：{average_fat_infiltration_ratio}")
else:
    print("目录中未找到任何图片。")
# Out:
# 00333.png 的脂肪浸润率为：0.6157601115760112
# 平均脂肪浸润率为：0.6157601115760112

# %%
import os
import cv2

# 设置输入目录和输出目录
mask_dir = r'C:\Users\Administrator\Desktop\mode\test\test3'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\test2'
image_dir = r'C:\Users\Administrator\Desktop\mode\test\test3'

# 确保输出目录存在，如果不存在则创建
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 遍历输入目录下的所有图片文件
for filename in os.listdir(mask_dir):
    if filename.endswith('.png') or filename.endswith('.jpg'):
        # 读取图片
        img_path = os.path.join(mask_dir, filename)
        img = cv2.imread(img_path)

        # 反色处理
        inverted_img = cv2.bitwise_not(img)

        # 转换为灰度图像
        gray = cv2.cvtColor(inverted_img, cv2.COLOR_BGR2GRAY)

        # 检测轮廓
        contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        # 读取对应的图片
        image_path = os.path.join(image_dir, filename)
        image = cv2.imread(image_path)

        # 用红色线条标出轮廓，并调整线条粗细为1
        img_contours = cv2.drawContours(image.copy(), contours, -1, (0, 0, 255), 2)

        # 保存标出轮廓后的图片到输出目录
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, img_contours)

        print(f'Processed: {filename}')

print('轮廓检测并标出轮廓完成，并保存至指定目录。')
# Out:
# Processed: 1.png
# Processed: 2.png
# Processed: 3.png
# Processed: 4.png
# Processed: 5.png
# Processed: 6.png
# Processed: 7.png
# 轮廓检测并标出轮廓完成，并保存至指定目录。

# %%
import cv2
import numpy as np
import os

def preprocess_image(image):
    # 使用直方图均衡化增强图像对比度
    equalized_image = cv2.equalizeHist(image)
    return equalized_image

def extract_fat_tissue_mask(image_dir, output_dir):
    # 遍历图片文件夹下的所有MRI图片
    for image_name in os.listdir(image_dir):
        if image_name.endswith(".png") or image_name.endswith(".jpg"):
            image_path = os.path.join(image_dir, image_name)

            # 读取MRI图片
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # 对图像进行预处理
            preprocessed_image = preprocess_image(image)

            # 使用信号阈值方法提取高信号部分
            _, thresholded_image = cv2.threshold(preprocessed_image, 175, 255, cv2.THRESH_BINARY)

            # 将提取的高信号部分作为mask
            fat_tissue_mask = thresholded_image

            # 保存mask图片
            mask_output_path = os.path.join(output_dir, image_name.split('.')[0] + '_mask.png')
            cv2.imwrite(mask_output_path, fat_tissue_mask)

# 调用函数并传入路径和参数值
image_dir = r'C:\Users\Administrator\Desktop\mode\test\test3'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\test3'
extract_fat_tissue_mask(image_dir, output_dir)

    # 使用直方图均衡化增强图像对比度后二值化mask

# %%
import cv2
import os

# 输入输出路径
image_dir = r'C:\Users\Administrator\Desktop\mode\test\test3'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\test3'

# 确保输出目录存在
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 获取输入目录下所有图片文件名
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith('.png')]

# 对每张图片进行线性插值方法的4倍分辨率增大并保存
for image_file in image_files:
    # 读取图片
    image = cv2.imread(image_file)

    if image is None:
        print(f"无法读取图片: {image_file}")
        continue

    # 将图像分辨率增大4倍
    resized_image = cv2.resize(image, None, fx=4, fy=4, interpolation=cv2.INTER_LINEAR)

    # 构造输出文件路径
    output_file = os.path.join(output_dir, os.path.basename(image_file))

    # 保存处理后的图像
    cv2.imwrite(output_file, resized_image)

# 将图像分辨率增大4倍

# %%
import cv2
import os

# 输入输出路径
image_dir = r'C:\Users\Administrator\Desktop\mode\test\out'
output_dir = r'C:\Users\Administrator\Desktop\mode\test\out7'


# 确保输出目录存在
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 获取输入目录下所有图片文件名
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith('.png')]

# 对每张图片进行直方图均衡化和高斯滤波
for image_file in image_files:
    # 读取图片
    image = cv2.imread(image_file)

    if image is None:
        print(f"无法读取图片: {image_file}")
        continue

    # 直方图均衡化
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    equalized_image = cv2.equalizeHist(gray_image)

    # 高斯滤波
    blurred_image = cv2.GaussianBlur(equalized_image, (7, 7), 0)

    # 构造输出文件路径
    output_file = os.path.join(output_dir, os.path.basename(image_file))

    # 保存处理后的图像
    cv2.imwrite(output_file, blurred_image)

# 直方图均衡化和高斯滤波

# %%
import os
import cv2
import numpy as np

def calculate_intensity_diff(image_path, output_path):
    # 遍历输出目录中的所有图像文件
    for filename in os.listdir(image_path):
        if filename.endswith('.png') or filename.endswith('.jpg'):
            try:
                # 构造图像文件路径
                image_file = os.path.join(image_path, filename)

                # 读取图像
                image = cv2.imread(image_file)

                if image is None:
                    raise Exception(f'Failed to load image: {image_file}')

                # 将非关键区域设为NaN，使其不纳入计算
                image_float = image.astype(float)
                image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                image_float[image_gray == 0] = np.nan

                # 计算信号强度的方差
                intensity_variance = np.nanvar(image_float)

                # 计算信号强度的极差
                intensity_range = np.nanmax(image_float) - np.nanmin(image_float)

                # 计算信号强度的梯度
                gradient_x = cv2.Sobel(image_gray, cv2.CV_64F, 1, 0, ksize=3)
                gradient_y = cv2.Sobel(image_gray, cv2.CV_64F, 0, 1, ksize=3)
                gradient_magnitude = np.sqrt(gradient_x**2 + gradient_y**2)
                intensity_gradient = np.nanmean(gradient_magnitude)

                # 输出结果
                print(f"Image: {filename}")
                print("Intensity Variance:", intensity_variance)
                print("Intensity Range:", intensity_range)
                print("Intensity Gradient:", intensity_gradient)

                # 将结果写入文件
                output_file = os.path.join(output_path, f"{os.path.splitext(filename)[0]}.txt")
                with open(output_file, "w") as f:
                    f.write(f"Image: {filename}\n")
                    f.write(f"Intensity Variance: {intensity_variance}\n")
                    f.write(f"Intensity Range: {intensity_range}\n")
                    f.write(f"Intensity Gradient: {intensity_gradient}\n")

                print(f"Results saved to: {output_file}")
            except Exception as e:
                print(f'Error processing {filename}: {e}')

# 输入路径和输出路径
image_path = r"C:\Users\Administrator\Desktop\mode\test\out"  # 输出目录路径
output_path = r"C:\Users\Administrator\Desktop\mode\test\out2"  # 输出文件保存路径

# 计算信号强度差异程度
calculate_intensity_diff(image_path, output_path)

# Intensity Variance（信号强度方差）：方差表示图像像素值的分散程度。在这里，信号强度方差的值越大，意味着图像中的像素值越分散，图像的对比度可能会更高。

# Intensity Range（信号强度极差）：极差是指图像中像素值的最大值与最小值之间的差异。在这里，信号强度极差的值表示图像的动态范围，即图像中亮度的变化范围。较大的极差意味着图像中存在较大的亮度差异。

# Intensity Gradient（信号强度梯度）：梯度表示图像中像素值的变化率或变化速度。在这里，信号强度梯度的值表示图像中亮度的变化速度。较大的梯度值可能意味着图像中存在较强的边缘或细节。

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def calculate_intensity_distribution(image_path, output_path):
    # 遍历输出目录中的所有图像文件
    for filename in os.listdir(image_path):
        if filename.endswith('.png') or filename.endswith('.jpg'):
            try:
                # 构造图像文件路径
                image_file = os.path.join(image_path, filename)

                # 读取图像
                image = cv2.imread(image_file)
                if image is None:
                    raise Exception(f'Failed to load image: {image_file}')
                    
                # 将非关键区域设为NaN，使其不纳入计算
                image_float = image.astype(float)
                image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                image_float[image_gray == 0] = np.nan
                


                # 将图像转换为灰度图像
                image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # 提取椎间盘区域内的像素值
                disc_region = image_gray[image_gray > 0]

                # 计算分布的偏态和峰度
                skewness = np.nan if len(disc_region) == 0 else np.nanmean((disc_region - np.nanmean(disc_region))**3) / (np.nanstd(disc_region)**3)
                kurtosis = np.nan if len(disc_region) == 0 else np.nanmean((disc_region - np.nanmean(disc_region))**4) / (np.nanstd(disc_region)**4) - 3

                # 绘制信号强度直方图
                plt.figure()
                plt.hist(disc_region, bins=50, color='blue', alpha=0.7)
                plt.title('Intensity Distribution')
                plt.xlabel('Intensity')
                plt.ylabel('Frequency')
                plt.grid(True)
                plt.savefig(os.path.join(output_path, f"{os.path.splitext(filename)[0]}_histogram.png"))

                # 输出结果
                print(f"Image: {filename}")
                print("Skewness:", skewness)
                print("Kurtosis:", kurtosis)

                # 将结果写入文件
                output_file = os.path.join(output_path, f"{os.path.splitext(filename)[0]}_stats.txt")
                with open(output_file, "w") as f:
                    f.write(f"Image: {filename}\n")
                    f.write(f"Skewness: {skewness}\n")
                    f.write(f"Kurtosis: {kurtosis}\n")

                print(f"Results saved to: {output_file}")
            except Exception as e:
                print(f'Error processing {filename}: {e}')

# 输入路径和输出路径
image_path = r"C:\Users\Administrator\Desktop\mode\test\out"  # 输出目录路径
output_path = r"C:\Users\Administrator\Desktop\mode\test\out2"  # 输出文件保存路径

# 计算信号强度分布
calculate_intensity_distribution(image_path, output_path)

# 偏态（Skewness）：偏态是描述分布对称性的统计量之一，通常用于分析椎间盘MRI图像中像素信号强度的分布。偏态值表示分布曲线相对于平均值的偏斜程度，可用于判断分布的对称性和偏向。在科学研究中，偏态的计算常采用高阶统计量，如三阶中心矩，其正负值代表分布的右偏或左偏程度。

# 峰度（Kurtosis）：峰度是描述分布形态尖度的统计量，在椎间盘MRI图像分析中常用于衡量像素信号强度分布的峰度或集中程度。峰度值反映了分布曲线的峰值高度和尖度，提供了对椎间盘MRI图像信号分布形态的定量描述。在科学研究中，峰度常使用四阶中心矩进行计算，其数值与正态分布相比较。

# 直方图（Histogram）：直方图是一种展示数据分布情况的图形化工具，在椎间盘MRI图像分析中常用于可视化像素信号强度的分布情况。直方图将像素信号强度划分为若干区间，并统计每个区间内像素的数量或频率，从而形成分布的柱状图。通过直方图，科学研究者可以直观地观察图像中像素信号强度的分布形态、峰值位置和分布范围，为进一步分析提供了重要参考依据。

# %%
import cv2
import numpy as np
import os

def calculate_mask_area_and_perimeter(image_path, fov_cm):
    # 加载灰度图像
    image_gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # 将图像反色
    inverted_image = cv2.bitwise_not(image_gray)

    # 计算像素宽度和高度（厘米）
    width, height = inverted_image.shape[::-1]
    pixel_width = fov_cm / width  # 每个像素的宽度（厘米）
    pixel_height = fov_cm / height  # 每个像素的高度（厘米）

    # 计算掩码面积
    black_pixels = np.sum(inverted_image == 255)  # 统计白色像素数量（灰度值为255的像素）
    mask_area_cm2 = black_pixels * (pixel_width * pixel_height)  # 面积（平方厘米）

    # 查找轮廓以计算周长
    contours, _ = cv2.findContours(inverted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    perimeter = 0
    for contour in contours:
        perimeter += cv2.arcLength(contour, True)  # 周长（像素）

    # 周长转换为厘米
    perimeter_cm = perimeter * pixel_width

    return mask_area_cm2, perimeter_cm

def calculate_mask_area_and_perimeter_for_folder(folder_path, fov_cm):
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.png') or f.lower().endswith('.jpg')]

    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        mask_area, perimeter = calculate_mask_area_and_perimeter(image_path, fov_cm)

        # 确保面积大于零，避免除以零或非正数
        if mask_area > 0:
            # 计算面积和周长的比值
            ratio = perimeter / mask_area

            print(f"图像 {image_file} 的掩码面积（平方厘米）：{mask_area}")
            print(f"图像 {image_file} 的轮廓周长（厘米）：{perimeter}")
            print(f"图像 {image_file} 的面积与周长的比值：{ratio}")
        else:
            print(f"图像 {image_file} 的掩码面积为零，无法计算周长和比值。")

# 示例用法
folder_path = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\intervertebral disc'  # 替换为你的文件夹路径
fov_cm = 20  # 视野大小（厘米）
calculate_mask_area_and_perimeter_for_folder(folder_path, fov_cm)

# %%
import cv2
import os

# 定义文件夹路径
folder_path = r'C:\Users\Administrator\Desktop\mode\test\mask4'

# 定义结果保存文件夹路径
result_folder = r'C:\Users\Administrator\Desktop\mode\test\labels'

# 获取文件夹中所有图片的文件名
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# 循环处理每张图片
for image_file in image_files:
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 查找边界
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 假设只有一个边界
    boundary = contours[0]

    # 计算边界的面积
    boundary_area = cv2.contourArea(boundary)

    # 计算凸包
    convex_hull = cv2.convexHull(boundary)

    # 计算凸包的面积
    convex_hull_area = cv2.contourArea(convex_hull)

    # 计算凹凸性指标
    convexity_indicator = boundary_area/convex_hull_area 

    print("图像 {} 的边界的凹凸性指标：{}".format(image_file, convexity_indicator))

    # 将凸包可视化在预处理图像上
    convex_hull_image = original_image.copy()
    cv2.drawContours(convex_hull_image, [convex_hull], -1, (0, 255, 0), 2)  # 在原图像上绘制凸包

    # 保存结果图像到指定文件夹
    result_file_path = os.path.join(result_folder, image_file)
    cv2.imwrite(result_file_path, convex_hull_image)

print("结果已保存到指定文件夹：{}".format(result_folder))
# Out:
# 图像 00032.png 的边界的凹凸性指标：0.9815878627191045
# 图像 00139.png 的边界的凹凸性指标：0.919359058207979
# 结果已保存到指定文件夹：C:\Users\Administrator\Desktop\mode\test\labels

# %%
import cv2
import os

# 定义文件夹路径
folder_path = r'C:\Users\Administrator\Desktop\mode\segement\train\masks\intervertebraldisc'

# 获取文件夹中所有图片的文件名
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# 循环处理每张图片
for image_file in image_files:
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 查找边界
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 假设只有一个边界
    boundary = contours[0]

    # 计算轮廓质心
    M = cv2.moments(boundary)
    cx = int(M['m10'] / M['m00'])  # 轮廓质心的x坐标
    cy = int(M['m01'] / M['m00'])  # 轮廓质心的y坐标

    # 将轮廓分为上下两半边界，仅保留下半边界
    lower_half_boundary = boundary[boundary[:, :, 1] >= cy]

    # 计算下半边界的凹凸性指标
    lower_convexity_indicator = cv2.contourArea(cv2.convexHull(lower_half_boundary)) / cv2.contourArea(lower_half_boundary)

    print("图像 {} 的下半边界凹凸性指标：{}".format(image_file, lower_convexity_indicator))

# 关闭窗口
cv2.destroyAllWindows()

# %%
import cv2
import os

# 定义文件夹路径
folder_path =  r'C:\Users\Administrator\Desktop\mode\segement\train\masks\intervertebraldisc'

# 获取文件夹中所有图片的文件名
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# 循环处理每张图片
for image_file in image_files:
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 查找边界
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 假设只有一个边界
    boundary = contours[0]

    # 计算轮廓质心
    M = cv2.moments(boundary)
    cx = int(M['m10'] / M['m00'])  # 轮廓质心的x坐标
    cy = int(M['m01'] / M['m00'])  # 轮廓质心的y坐标

    # 将轮廓分为左右两半边界
    left_half_boundary = boundary[boundary[:, :, 0] < cx]
    right_half_boundary = boundary[boundary[:, :, 0] >= cx]

    # 计算左右半边界的凹凸性指标
    left_convexity_indicator = cv2.contourArea(cv2.convexHull(left_half_boundary)) / cv2.contourArea(left_half_boundary)
    right_convexity_indicator = cv2.contourArea(cv2.convexHull(right_half_boundary)) / cv2.contourArea(right_half_boundary)

    # 计算对称性指标
    symmetry_index = abs(left_convexity_indicator - right_convexity_indicator)
    print("图像 {} 的左右半边界对称性指标：{}".format(image_file, symmetry_index))

# 关闭窗口
cv2.destroyAllWindows()

# %%
import cv2
import os
import numpy as np

def calculate_half_symmetry_score(image_half):
    # 将图像分成左右两半
    width_half = image_half.shape[1] // 2
    left_half = image_half[:, :width_half]
    right_half = image_half[:, width_half:]

    # 计算左右半边的对称性分数
    diff = np.abs(left_half.astype(int) - np.flip(right_half, axis=1).astype(int))
    symmetry_score = np.mean(diff) / 255.0  # 归一化到0到1的范围

    return symmetry_score

# 定义文件夹路径
folder_path = r'C:\Users\Administrator\Desktop\mode\segement\train\masks\intervertebraldisc'

# 获取文件夹中所有图片的文件名
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# 循环处理每张图片
for image_file in image_files:
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 将图像分成左右两半并计算对称性分数
    symmetry_score = calculate_half_symmetry_score(gray_image)

    print("图像 {} 的左右半边对称性分数：{}".format(image_file, symmetry_score))

# 关闭窗口
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import os

def curvature_numerical_diff(points):
    """
    使用数值微分法计算轮廓的曲率
    """
    n = len(points)
    curvature = np.zeros(n)

    for i in range(1, n - 1):
        dx = points[i + 1][0] - points[i - 1][0]
        dy = points[i + 1][1] - points[i - 1][1]
        ds = np.sqrt(dx ** 2 + dy ** 2)

        if ds == 0:
            curvature[i] = 0
        else:
            curvature[i] = 2 * (dx * points[i][1] - dy * points[i][0]) / (ds ** 3)

    return curvature

# 定义文件夹路径
folder_path = r'C:\Users\Administrator\Desktop\mode\test\mask4'

# 获取文件夹中所有图片的文件名
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# 循环处理每张图片
for image_file in image_files:
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 查找边界
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 假设只有一个边界
    boundary = contours[0][:, 0, :]  # 注意这里的索引取法

    # 计算曲率
    curvature = curvature_numerical_diff(boundary)

    # 计算均值、极差、局部极值点数量和曲率方差
    mean_curvature = np.mean(curvature)
    range_curvature = np.max(curvature) - np.min(curvature)
    num_local_extrema = np.sum((np.diff(np.sign(np.diff(curvature))) != 0) & (curvature[1:-1] != 0))
    curvature_variance = np.var(curvature)

    # 输出每张图片的曲率统计信息
    print("图像 {} 的曲率均值：{}".format(image_file, mean_curvature))
    print("图像 {} 的曲率极差：{}".format(image_file, range_curvature))
    print("图像 {} 的曲率局部极值点数量：{}".format(image_file, num_local_extrema))
    print("图像 {} 的曲率方差：{}".format(image_file, curvature_variance))

# 关闭窗口
cv2.destroyAllWindows()
# Out:
# 图像 00012.png 的曲率均值：2.948848101394499
# 图像 00012.png 的曲率极差：249.54518628897648
# 图像 00012.png 的曲率局部极值点数量：99
# 图像 00012.png 的曲率方差：2540.8515452065594
# 图像 00032.png 的曲率均值：12.409496644462047
# 图像 00032.png 的曲率极差：510.3905631679353
# 图像 00032.png 的曲率局部极值点数量：93
# 图像 00032.png 的曲率方差：4395.0909895694795

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import splprep, splev

def curvature_numerical_diff(points, num_neighbors=3):
    """
    使用数值微分法计算轮廓的曲率
    """
    n = len(points)
    curvature = np.zeros(n)

    for i in range(num_neighbors, n - num_neighbors):
        dx = points[i + num_neighbors][0] - points[i - num_neighbors][0]
        dy = points[i + num_neighbors][1] - points[i - num_neighbors][1]
        ds = np.sqrt(dx ** 2 + dy ** 2)

        if ds == 0:
            curvature[i] = 0
        else:
            curvature[i] = 2 * (dx * points[i][1] - dy * points[i][0]) / (ds ** 3)

    return curvature

def interpolate_contour(points, num_points=150):
    """
    使用样条插值方法对轮廓进行插值，使其连续
    """
    tck, _ = splprep(points.T, s=0, per=1)  # 样条插值
    u_new = np.linspace(0, 1, num_points)
    x_new, y_new = splev(u_new, tck)
    interpolated_contour = np.column_stack((x_new, y_new)).astype(int)
    return interpolated_contour

# 定义文件夹路径
folder_path = r'C:\Users\Administrator\Desktop\mode\test\mask4'

# 获取文件夹中所有图片的文件名
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# 循环处理每张图片
for image_file in image_files:
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 查找边界
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 假设只有一个边界
    boundary = contours[0][:, 0, :]  # 注意这里的索引取法

    # 计算曲率
    curvature = curvature_numerical_diff(boundary)

    # 归一化曲率值
    min_normalized_value = -1
    max_normalized_value = 1
    normalized_curvature = min_normalized_value + (max_normalized_value - min_normalized_value) * (curvature - np.min(curvature)) / (np.max(curvature) - np.min(curvature))

    # 样条插值
    interpolated_boundary = interpolate_contour(boundary)

    # 创建一个与原始图像大小相同的空白图像
    blank_image = np.zeros_like(original_image)

    # 应用颜色映射
    colors = plt.cm.jet((normalized_curvature + 1) / 2)[:,:3]  # 根据曲率值获取颜色
    for point, color in zip(interpolated_boundary, colors):
        cv2.circle(blank_image, (point[0], point[1]), 1, (int(color[2]*255), int(color[1]*255), int(color[0]*255)), -1)  # 绘制圆点，注意颜色通道的顺序和范围

    # 显示轮廓
    cv2.imshow('Curvature Contour', blank_image)
    cv2.waitKey(0)

# 关闭窗口
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import os

def normalize_distance_metrics(mean_distance, distance_variance, max_distance, min_distance, disc_area):
    """
    对距离指标进行归一化处理，消除椎间盘大小的影响
    """
    mean_distance_normalized = mean_distance / disc_area
    variance_normalized = distance_variance / (disc_area ** 2)
    max_distance_normalized = max_distance / np.sqrt(disc_area)
    min_distance_normalized = min_distance / np.sqrt(disc_area)
    distance_ratio_normalized = max_distance_normalized / min_distance_normalized if min_distance_normalized != 0 else np.inf
    return mean_distance_normalized, variance_normalized, distance_ratio_normalized

# 定义文件夹路径
folder_path = r'C:\Users\Administrator\Desktop\mode\segement\train\masks\intervertebraldisc'

# 循环处理每张图片
for image_file in os.listdir(folder_path):
    # 读取彩色图像
    original_image = cv2.imread(os.path.join(folder_path, image_file))

    # 反色处理
    inverted_image = cv2.bitwise_not(original_image)

    # 转换为灰度图像
    gray_image = cv2.cvtColor(inverted_image, cv2.COLOR_BGR2GRAY)

    # 查找边界
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 假设只有一个边界
    boundary = contours[0][:, 0, :]  # 注意这里的索引取法

    # 计算椎间盘面积
    disc_area = cv2.contourArea(boundary)

    # 计算质心
    M = cv2.moments(boundary)
    if M["m00"] != 0:
        centroid_x = int(M["m10"] / M["m00"])
        centroid_y = int(M["m01"] / M["m00"])
        centroid = np.array([centroid_x, centroid_y])

        # 计算质心到轮廓上每个点的距离
        distances = np.linalg.norm(boundary - centroid, axis=1)

        # 计算距离相关指标
        mean_distance = np.mean(distances)
        distance_variance = np.var(distances)
        max_distance = np.max(distances)
        min_distance = np.min(distances)

        # 归一化距离指标
        mean_distance_normalized, variance_normalized, distance_ratio_normalized = normalize_distance_metrics(mean_distance, distance_variance, max_distance, min_distance, disc_area)

        # 输出每张图片的距离统计信息
        print("图像 {} 的质心到轮廓上点的归一化平均距离：{}".format(image_file, mean_distance_normalized))
        print("图像 {} 的质心到轮廓上点的归一化距离方差：{}".format(image_file, variance_normalized))
        print("图像 {} 的质心到轮廓上点的归一化最大距离与最小距离的比值：{}".format(image_file, distance_ratio_normalized))
    else:
        print("图像 {} 的边界找不到，无法计算质心".format(image_file))

# 关闭窗口
cv2.destroyAllWindows()
# Out:
# 图像 00001.png 的质心到轮廓上点的归一化平均距离：0.006199519148946618
# 图像 00001.png 的质心到轮廓上点的归一化距离方差：3.924923950786631e-07
# 图像 00001.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6654000543787995
# 图像 00002.png 的质心到轮廓上点的归一化平均距离：0.005933585885992041
# 图像 00002.png 的质心到轮廓上点的归一化距离方差：2.5936469994908116e-07
# 图像 00002.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4975470138942313
# 图像 00003.png 的质心到轮廓上点的归一化平均距离：0.005922918206549225
# 图像 00003.png 的质心到轮廓上点的归一化距离方差：1.812927337521218e-07
# 图像 00003.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4684060120471505
# 图像 00004.png 的质心到轮廓上点的归一化平均距离：0.005672048449136906
# 图像 00004.png 的质心到轮廓上点的归一化距离方差：1.951344343391986e-07
# 图像 00004.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3588498920210588
# 图像 00005.png 的质心到轮廓上点的归一化平均距离：0.005642258233808325
# 图像 00005.png 的质心到轮廓上点的归一化距离方差：2.7717382384887946e-07
# 图像 00005.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4427209626360933
# 图像 00006.png 的质心到轮廓上点的归一化平均距离：0.005579756780722172
# 图像 00006.png 的质心到轮廓上点的归一化距离方差：1.8156132701564625e-07
# 图像 00006.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4180019794534509
# 图像 00007.png 的质心到轮廓上点的归一化平均距离：0.005345754687036264
# 图像 00007.png 的质心到轮廓上点的归一化距离方差：9.429636005051991e-08
# 图像 00007.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2929460665525132
# 图像 00008.png 的质心到轮廓上点的归一化平均距离：0.005114726092902036
# 图像 00008.png 的质心到轮廓上点的归一化距离方差：1.319474405456095e-07
# 图像 00008.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3764797083118632
# 图像 00009.png 的质心到轮廓上点的归一化平均距离：0.005287332559369259
# 图像 00009.png 的质心到轮廓上点的归一化距离方差：2.2748838431679725e-07
# 图像 00009.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6472618196846165
# 图像 00010.png 的质心到轮廓上点的归一化平均距离：0.005749453053616878
# 图像 00010.png 的质心到轮廓上点的归一化距离方差：3.4139021132766134e-07
# 图像 00010.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4577379737113252
# 图像 00011.png 的质心到轮廓上点的归一化平均距离：0.00549138960431853
# 图像 00011.png 的质心到轮廓上点的归一化距离方差：1.9286488499887539e-07
# 图像 00011.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4576407490489491
# 图像 00012.png 的质心到轮廓上点的归一化平均距离：0.00569343815498521
# 图像 00012.png 的质心到轮廓上点的归一化距离方差：3.2787478525719735e-07
# 图像 00012.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5421324809602082
# 图像 00013.png 的质心到轮廓上点的归一化平均距离：0.005356058883148762
# 图像 00013.png 的质心到轮廓上点的归一化距离方差：3.1176972948071863e-07
# 图像 00013.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6689533862290475
# 图像 00014.png 的质心到轮廓上点的归一化平均距离：0.005445588729488199
# 图像 00014.png 的质心到轮廓上点的归一化距离方差：2.1983455889663397e-07
# 图像 00014.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5013955531401413
# 图像 00015.png 的质心到轮廓上点的归一化平均距离：0.005243094042942991
# 图像 00015.png 的质心到轮廓上点的归一化距离方差：2.355767606553993e-07
# 图像 00015.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.55859024115481
# 图像 00016.png 的质心到轮廓上点的归一化平均距离：0.004845558773334428
# 图像 00016.png 的质心到轮廓上点的归一化距离方差：2.2344540417786862e-07
# 图像 00016.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5010746856644073
# 图像 00017.png 的质心到轮廓上点的归一化平均距离：0.004814230272164442
# 图像 00017.png 的质心到轮廓上点的归一化距离方差：1.7248294561593473e-07
# 图像 00017.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.484464554927734
# 图像 00018.png 的质心到轮廓上点的归一化平均距离：0.004654042140281699
# 图像 00018.png 的质心到轮廓上点的归一化距离方差：1.902463003080978e-07
# 图像 00018.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4950527916889584
# 图像 00019.png 的质心到轮廓上点的归一化平均距离：0.005096258358453443
# 图像 00019.png 的质心到轮廓上点的归一化距离方差：2.6087040596627784e-07
# 图像 00019.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5184890940111178
# 图像 00020.png 的质心到轮廓上点的归一化平均距离：0.004991663568747154
# 图像 00020.png 的质心到轮廓上点的归一化距离方差：1.820985062251723e-07
# 图像 00020.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.386750490563073
# 图像 00021.png 的质心到轮廓上点的归一化平均距离：0.004889225589100583
# 图像 00021.png 的质心到轮廓上点的归一化距离方差：2.1586507027990002e-07
# 图像 00021.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4834889185747888
# 图像 00022.png 的质心到轮廓上点的归一化平均距离：0.005160623611854969
# 图像 00022.png 的质心到轮廓上点的归一化距离方差：3.1977294163728883e-07
# 图像 00022.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4417570592960292
# 图像 00023.png 的质心到轮廓上点的归一化平均距离：0.005012969945946532
# 图像 00023.png 的质心到轮廓上点的归一化距离方差：2.79385744406333e-07
# 图像 00023.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.466129572376737
# 图像 00024.png 的质心到轮廓上点的归一化平均距离：0.005009280762523844
# 图像 00024.png 的质心到轮廓上点的归一化距离方差：2.891685089104653e-07
# 图像 00024.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4458974614496525
# 图像 00025.png 的质心到轮廓上点的归一化平均距离：0.0052304633166142655
# 图像 00025.png 的质心到轮廓上点的归一化距离方差：1.21950235901881e-07
# 图像 00025.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3068911973725708
# 图像 00026.png 的质心到轮廓上点的归一化平均距离：0.0048738159580574755
# 图像 00026.png 的质心到轮廓上点的归一化距离方差：1.743470599528712e-07
# 图像 00026.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4700175898558676
# 图像 00027.png 的质心到轮廓上点的归一化平均距离：0.005112591527002058
# 图像 00027.png 的质心到轮廓上点的归一化距离方差：2.868208584059852e-07
# 图像 00027.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.433426774933538
# 图像 00029.png 的质心到轮廓上点的归一化平均距离：0.006074990475847343
# 图像 00029.png 的质心到轮廓上点的归一化距离方差：3.4038627485893024e-07
# 图像 00029.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5811388300841898
# 图像 00030.png 的质心到轮廓上点的归一化平均距离：0.005812575087946114
# 图像 00030.png 的质心到轮廓上点的归一化距离方差：2.6517838774203863e-07
# 图像 00030.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5093005339151582
# 图像 00031.png 的质心到轮廓上点的归一化平均距离：0.005704115368448882
# 图像 00031.png 的质心到轮廓上点的归一化距离方差：3.809413354333956e-07
# 图像 00031.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6108304039109562
# 图像 00032.png 的质心到轮廓上点的归一化平均距离：0.005726677661751775
# 图像 00032.png 的质心到轮廓上点的归一化距离方差：2.91759392015815e-07
# 图像 00032.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5082973163681996
# 图像 00033.png 的质心到轮廓上点的归一化平均距离：0.005921910609271675
# 图像 00033.png 的质心到轮廓上点的归一化距离方差：6.211688290079917e-07
# 图像 00033.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5434418716009737
# 图像 00034.png 的质心到轮廓上点的归一化平均距离：0.005673601509235639
# 图像 00034.png 的质心到轮廓上点的归一化距离方差：3.376768992114309e-07
# 图像 00034.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4485564832957443
# 图像 00035.png 的质心到轮廓上点的归一化平均距离：0.005576729701707953
# 图像 00035.png 的质心到轮廓上点的归一化距离方差：3.0961321043678707e-07
# 图像 00035.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.417421265884881
# 图像 00036.png 的质心到轮廓上点的归一化平均距离：0.005790332010582596
# 图像 00036.png 的质心到轮廓上点的归一化距离方差：5.387496408855876e-07
# 图像 00036.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6169327298308334
# 图像 00037.png 的质心到轮廓上点的归一化平均距离：0.0054718365947772326
# 图像 00037.png 的质心到轮廓上点的归一化距离方差：3.069672071181665e-07
# 图像 00037.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4442530546219094
# 图像 00038.png 的质心到轮廓上点的归一化平均距离：0.0052850979771929645
# 图像 00038.png 的质心到轮廓上点的归一化距离方差：2.145672673936331e-07
# 图像 00038.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4052462350535138
# 图像 00039.png 的质心到轮廓上点的归一化平均距离：0.005622905680150144
# 图像 00039.png 的质心到轮廓上点的归一化距离方差：2.9793448840099434e-07
# 图像 00039.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5367457360047752
# 图像 00040.png 的质心到轮廓上点的归一化平均距离：0.005790429690229771
# 图像 00040.png 的质心到轮廓上点的归一化距离方差：6.463844506528929e-07
# 图像 00040.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.607289781255103
# 图像 00041.png 的质心到轮廓上点的归一化平均距离：0.005640661433619471
# 图像 00041.png 的质心到轮廓上点的归一化距离方差：4.0787405238978994e-07
# 图像 00041.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6292980572409517
# 图像 00042.png 的质心到轮廓上点的归一化平均距离：0.005490277225212591
# 图像 00042.png 的质心到轮廓上点的归一化距离方差：4.5013853134851636e-07
# 图像 00042.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.734101092492814
# 图像 00043.png 的质心到轮廓上点的归一化平均距离：0.005261183794882399
# 图像 00043.png 的质心到轮廓上点的归一化距离方差：4.0931742972801027e-07
# 图像 00043.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6201686961595632
# 图像 00044.png 的质心到轮廓上点的归一化平均距离：0.006093925708363294
# 图像 00044.png 的质心到轮廓上点的归一化距离方差：6.124066133859034e-07
# 图像 00044.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5242334700540061
# 图像 00045.png 的质心到轮廓上点的归一化平均距离：0.005604985497487784
# 图像 00045.png 的质心到轮廓上点的归一化距离方差：5.527510851260717e-07
# 图像 00045.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.641520853738975
# 图像 00046.png 的质心到轮廓上点的归一化平均距离：0.005276272104423401
# 图像 00046.png 的质心到轮廓上点的归一化距离方差：4.4277931297090415e-07
# 图像 00046.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5403107389605424
# 图像 00047.png 的质心到轮廓上点的归一化平均距离：0.005198850588648054
# 图像 00047.png 的质心到轮廓上点的归一化距离方差：4.2655636456658137e-07
# 图像 00047.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.545867356002106
# 图像 00048.png 的质心到轮廓上点的归一化平均距离：0.005223496033674719
# 图像 00048.png 的质心到轮廓上点的归一化距离方差：4.196500141420335e-07
# 图像 00048.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4959628464854247
# 图像 00049.png 的质心到轮廓上点的归一化平均距离：0.005171701277364732
# 图像 00049.png 的质心到轮廓上点的归一化距离方差：6.060192315979021e-07
# 图像 00049.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7586676426757377
# 图像 00050.png 的质心到轮廓上点的归一化平均距离：0.0054881122523659925
# 图像 00050.png 的质心到轮廓上点的归一化距离方差：6.090556945759998e-07
# 图像 00050.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.669432122042793
# 图像 00051.png 的质心到轮廓上点的归一化平均距离：0.005104724370673836
# 图像 00051.png 的质心到轮廓上点的归一化距离方差：6.075946455570667e-07
# 图像 00051.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7193986965591366
# 图像 00052.png 的质心到轮廓上点的归一化平均距离：0.005165075004763978
# 图像 00052.png 的质心到轮廓上点的归一化距离方差：5.546034826354513e-07
# 图像 00052.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6212299574736797
# 图像 00053.png 的质心到轮廓上点的归一化平均距离：0.005026576845925139
# 图像 00053.png 的质心到轮廓上点的归一化距离方差：4.4567130255477985e-07
# 图像 00053.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5610802542913038
# 图像 00054.png 的边界找不到，无法计算质心
# 图像 00055.png 的质心到轮廓上点的归一化平均距离：0.005797571276359023
# 图像 00055.png 的质心到轮廓上点的归一化距离方差：1.9207865314115195e-07
# 图像 00055.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.41266581191712
# 图像 00056.png 的质心到轮廓上点的归一化平均距离：0.005839715334220336
# 图像 00056.png 的质心到轮廓上点的归一化距离方差：1.9710335543245726e-07
# 图像 00056.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4413450761450048
# 图像 00057.png 的质心到轮廓上点的归一化平均距离：0.005816760120063915
# 图像 00057.png 的质心到轮廓上点的归一化距离方差：3.9233766099109966e-07
# 图像 00057.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5925022981717014
# 图像 00058.png 的质心到轮廓上点的归一化平均距离：0.005633868327398517
# 图像 00058.png 的质心到轮廓上点的归一化距离方差：5.21439227248085e-07
# 图像 00058.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.8890132310072194
# 图像 00059.png 的质心到轮廓上点的归一化平均距离：0.005389492527897106
# 图像 00059.png 的质心到轮廓上点的归一化距离方差：2.076782326181308e-07
# 图像 00059.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4534441853748634
# 图像 00060.png 的质心到轮廓上点的归一化平均距离：0.005217788048581708
# 图像 00060.png 的质心到轮廓上点的归一化距离方差：1.7898337654707626e-07
# 图像 00060.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4696525721551634
# 图像 00061.png 的质心到轮廓上点的归一化平均距离：0.005635724886240406
# 图像 00061.png 的质心到轮廓上点的归一化距离方差：2.789962655540703e-07
# 图像 00061.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4794012839134505
# 图像 00062.png 的质心到轮廓上点的归一化平均距离：0.00537402620339229
# 图像 00062.png 的质心到轮廓上点的归一化距离方差：3.145669748798381e-07
# 图像 00062.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5435852234249523
# 图像 00063.png 的质心到轮廓上点的归一化平均距离：0.005353400491738982
# 图像 00063.png 的质心到轮廓上点的归一化距离方差：2.805117121663724e-07
# 图像 00063.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4122448838932542
# 图像 00064.png 的质心到轮廓上点的归一化平均距离：0.005468867610283697
# 图像 00064.png 的质心到轮廓上点的归一化距离方差：1.989374579581389e-07
# 图像 00064.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3501693221383677
# 图像 00065.png 的质心到轮廓上点的归一化平均距离：0.00577534362901455
# 图像 00065.png 的质心到轮廓上点的归一化距离方差：2.5632590708495e-07
# 图像 00065.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4403109395856573
# 图像 00066.png 的质心到轮廓上点的归一化平均距离：0.005428516015897966
# 图像 00066.png 的质心到轮廓上点的归一化距离方差：2.031891782582483e-07
# 图像 00066.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3656429052820072
# 图像 00067.png 的质心到轮廓上点的归一化平均距离：0.005159201238396471
# 图像 00067.png 的质心到轮廓上点的归一化距离方差：1.230611026365917e-07
# 图像 00067.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2691929074426578
# 图像 00068.png 的质心到轮廓上点的归一化平均距离：0.005184031449751618
# 图像 00068.png 的质心到轮廓上点的归一化距离方差：2.1901790984292248e-07
# 图像 00068.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.389837879521261
# 图像 00069.png 的质心到轮廓上点的归一化平均距离：0.006004632720797346
# 图像 00069.png 的质心到轮廓上点的归一化距离方差：5.739644428711321e-07
# 图像 00069.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5298338934872162
# 图像 00070.png 的质心到轮廓上点的归一化平均距离：0.00583594526676684
# 图像 00070.png 的质心到轮廓上点的归一化距离方差：4.6868663025474553e-07
# 图像 00070.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4978834475135323
# 图像 00071.png 的质心到轮廓上点的归一化平均距离：0.005845718815992716
# 图像 00071.png 的质心到轮廓上点的归一化距离方差：5.752583211234363e-07
# 图像 00071.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5167826445361257
# 图像 00072.png 的质心到轮廓上点的归一化平均距离：0.005980574786792147
# 图像 00072.png 的质心到轮廓上点的归一化距离方差：4.740374297716938e-07
# 图像 00072.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.524512358439407
# 图像 00073.png 的质心到轮廓上点的归一化平均距离：0.006018343779936002
# 图像 00073.png 的质心到轮廓上点的归一化距离方差：5.296826718843042e-07
# 图像 00073.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7044432211623173
# 图像 00074.png 的质心到轮廓上点的归一化平均距离：0.0058891342354335805
# 图像 00074.png 的质心到轮廓上点的归一化距离方差：3.0365554258266616e-07
# 图像 00074.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.513326921402221
# 图像 00075.png 的质心到轮廓上点的归一化平均距离：0.006164549587839091
# 图像 00075.png 的质心到轮廓上点的归一化距离方差：2.777007470783301e-07
# 图像 00075.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4843475574247689
# 图像 00076.png 的质心到轮廓上点的归一化平均距离：0.006141271843968988
# 图像 00076.png 的质心到轮廓上点的归一化距离方差：6.971667519739052e-07
# 图像 00076.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.711867005402127
# 图像 00077.png 的质心到轮廓上点的归一化平均距离：0.005765408926566217
# 图像 00077.png 的质心到轮廓上点的归一化距离方差：6.744641142306307e-07
# 图像 00077.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.8207159219123952
# 图像 00078.png 的质心到轮廓上点的归一化平均距离：0.005664425813452564
# 图像 00078.png 的质心到轮廓上点的归一化距离方差：7.412675099978759e-07
# 图像 00078.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.860697698105306
# 图像 00079.png 的质心到轮廓上点的归一化平均距离：0.005839873693316739
# 图像 00079.png 的质心到轮廓上点的归一化距离方差：6.077371883950128e-07
# 图像 00079.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.565140386524545
# 图像 00080.png 的质心到轮廓上点的归一化平均距离：0.005711801323271259
# 图像 00080.png 的质心到轮廓上点的归一化距离方差：3.995867509154294e-07
# 图像 00080.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.538133173212445
# 图像 00081.png 的质心到轮廓上点的归一化平均距离：0.005600978807353944
# 图像 00081.png 的质心到轮廓上点的归一化距离方差：4.230822113944561e-07
# 图像 00081.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5643077777500858
# 图像 00082.png 的质心到轮廓上点的归一化平均距离：0.0054654489817163735
# 图像 00082.png 的质心到轮廓上点的归一化距离方差：4.715018434159873e-07
# 图像 00082.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6631496739759395
# 图像 00083.png 的质心到轮廓上点的归一化平均距离：0.006554555519108281
# 图像 00083.png 的质心到轮廓上点的归一化距离方差：7.160530876074719e-07
# 图像 00083.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6199316998629179
# 图像 00084.png 的质心到轮廓上点的归一化平均距离：0.005923403637246114
# 图像 00084.png 的质心到轮廓上点的归一化距离方差：4.815313912552466e-07
# 图像 00084.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4997789403863906
# 图像 00085.png 的质心到轮廓上点的归一化平均距离：0.005824340498568331
# 图像 00085.png 的质心到轮廓上点的归一化距离方差：4.3840120331529047e-07
# 图像 00085.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4965884376383718
# 图像 00086.png 的质心到轮廓上点的归一化平均距离：0.005718952212394104
# 图像 00086.png 的质心到轮廓上点的归一化距离方差：4.735223079699776e-07
# 图像 00086.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.547057200697827
# 图像 00087.png 的质心到轮廓上点的归一化平均距离：0.00641443087872088
# 图像 00087.png 的质心到轮廓上点的归一化距离方差：5.000555205905423e-07
# 图像 00087.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4382607914799004
# 图像 00088.png 的质心到轮廓上点的归一化平均距离：0.005789826158208651
# 图像 00088.png 的质心到轮廓上点的归一化距离方差：2.7262297552577575e-07
# 图像 00088.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6246182983656856
# 图像 00090.png 的质心到轮廓上点的归一化平均距离：0.005344186251710462
# 图像 00090.png 的质心到轮廓上点的归一化距离方差：2.3684396016170525e-07
# 图像 00090.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.417196509290771
# 图像 00091.png 的质心到轮廓上点的归一化平均距离：0.005244972877525643
# 图像 00091.png 的质心到轮廓上点的归一化距离方差：2.5491626151584137e-07
# 图像 00091.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5224156055302167
# 图像 00092.png 的质心到轮廓上点的归一化平均距离：0.005418911885288681
# 图像 00092.png 的质心到轮廓上点的归一化距离方差：1.7132629036500148e-07
# 图像 00092.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4211763238362494
# 图像 00093.png 的质心到轮廓上点的归一化平均距离：0.004901225099825883
# 图像 00093.png 的质心到轮廓上点的归一化距离方差：2.7541481459288404e-07
# 图像 00093.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4539053719034907
# 图像 00094.png 的质心到轮廓上点的归一化平均距离：0.004910541209945372
# 图像 00094.png 的质心到轮廓上点的归一化距离方差：2.5628821257381543e-07
# 图像 00094.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5754587396360935
# 图像 00095.png 的质心到轮廓上点的归一化平均距离：0.004962873673525358
# 图像 00095.png 的质心到轮廓上点的归一化距离方差：1.9377757856277997e-07
# 图像 00095.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4126348209613173
# 图像 00096.png 的质心到轮廓上点的归一化平均距离：0.004561869669692469
# 图像 00096.png 的质心到轮廓上点的归一化距离方差：1.1358088625107702e-07
# 图像 00096.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3095983071142963
# 图像 00097.png 的质心到轮廓上点的归一化平均距离：0.004336079763454444
# 图像 00097.png 的质心到轮廓上点的归一化距离方差：5.827900565367101e-08
# 图像 00097.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2608185680495279
# 图像 00098.png 的质心到轮廓上点的归一化平均距离：0.004305579642203601
# 图像 00098.png 的质心到轮廓上点的归一化距离方差：1.0683075135206305e-07
# 图像 00098.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3562740846247596
# 图像 00099.png 的边界找不到，无法计算质心
# 图像 00100.png 的质心到轮廓上点的归一化平均距离：0.004928346113275439
# 图像 00100.png 的质心到轮廓上点的归一化距离方差：4.483806230595832e-07
# 图像 00100.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.632243084574662
# 图像 00101.png 的质心到轮廓上点的归一化平均距离：0.005234482576556274
# 图像 00101.png 的质心到轮廓上点的归一化距离方差：1.0410818457918991e-06
# 图像 00101.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.951036284437665
# 图像 00102.png 的质心到轮廓上点的归一化平均距离：0.006918789811901274
# 图像 00102.png 的质心到轮廓上点的归一化距离方差：3.53450920624004e-07
# 图像 00102.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4919985437764618
# 图像 00103.png 的质心到轮廓上点的归一化平均距离：0.00636964587583803
# 图像 00103.png 的质心到轮廓上点的归一化距离方差：1.2739824976861272e-07
# 图像 00103.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2853864228284975
# 图像 00104.png 的质心到轮廓上点的归一化平均距离：0.006260566764646887
# 图像 00104.png 的质心到轮廓上点的归一化距离方差：1.123815132014116e-07
# 图像 00104.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2991554479925718
# 图像 00105.png 的质心到轮廓上点的归一化平均距离：0.006076840363295073
# 图像 00105.png 的质心到轮廓上点的归一化距离方差：1.1962733154107048e-07
# 图像 00105.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2578641509408808
# 图像 00107.png 的质心到轮廓上点的归一化平均距离：0.005777442743016661
# 图像 00107.png 的质心到轮廓上点的归一化距离方差：1.4019554614572632e-07
# 图像 00107.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.280085249596919
# 图像 00108.png 的质心到轮廓上点的归一化平均距离：0.006537432815903256
# 图像 00108.png 的质心到轮廓上点的归一化距离方差：1.972190011959706e-07
# 图像 00108.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3016843021531412
# 图像 00109.png 的质心到轮廓上点的归一化平均距离：0.006102434730066691
# 图像 00109.png 的质心到轮廓上点的归一化距离方差：4.4484991142610295e-07
# 图像 00109.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5319618848048555
# 图像 00110.png 的质心到轮廓上点的归一化平均距离：0.005486626352341038
# 图像 00110.png 的质心到轮廓上点的归一化距离方差：2.391875771039642e-07
# 图像 00110.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5092387589780305
# 图像 00111.png 的质心到轮廓上点的归一化平均距离：0.005403420106134422
# 图像 00111.png 的质心到轮廓上点的归一化距离方差：2.578603544181987e-07
# 图像 00111.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5044029052678642
# 图像 00112.png 的质心到轮廓上点的归一化平均距离：0.0055209398523381895
# 图像 00112.png 的质心到轮廓上点的归一化距离方差：3.790837173584198e-07
# 图像 00112.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5581608288425577
# 图像 00113.png 的质心到轮廓上点的归一化平均距离：0.0062158395744987185
# 图像 00113.png 的质心到轮廓上点的归一化距离方差：4.635596177040929e-07
# 图像 00113.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4344521815747258
# 图像 00114.png 的质心到轮廓上点的归一化平均距离：0.005862217721553724
# 图像 00114.png 的质心到轮廓上点的归一化距离方差：3.221135834172387e-07
# 图像 00114.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.417596660538816
# 图像 00115.png 的质心到轮廓上点的归一化平均距离：0.005879816437950479
# 图像 00115.png 的质心到轮廓上点的归一化距离方差：4.3372640664093955e-07
# 图像 00115.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.458369245118289
# 图像 00116.png 的质心到轮廓上点的归一化平均距离：0.005911453958613193
# 图像 00116.png 的质心到轮廓上点的归一化距离方差：4.209312533896317e-07
# 图像 00116.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5830705825823597
# 图像 00117.png 的质心到轮廓上点的归一化平均距离：0.005812467186318536
# 图像 00117.png 的质心到轮廓上点的归一化距离方差：3.562630868605703e-07
# 图像 00117.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.539819267420328
# 图像 00118.png 的质心到轮廓上点的归一化平均距离：0.0054641371615804304
# 图像 00118.png 的质心到轮廓上点的归一化距离方差：2.2037844820135765e-07
# 图像 00118.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4909951733868996
# 图像 00119.png 的质心到轮廓上点的归一化平均距离：0.005306211888975338
# 图像 00119.png 的质心到轮廓上点的归一化距离方差：1.2804248199581614e-07
# 图像 00119.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.388740021879013
# 图像 00120.png 的质心到轮廓上点的归一化平均距离：0.005328761330462755
# 图像 00120.png 的质心到轮廓上点的归一化距离方差：1.8047324645172595e-07
# 图像 00120.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3414272004463832
# 图像 00121.png 的质心到轮廓上点的归一化平均距离：0.0052836095092430955
# 图像 00121.png 的质心到轮廓上点的归一化距离方差：1.603709473028194e-07
# 图像 00121.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3880560927836747
# 图像 00122.png 的质心到轮廓上点的归一化平均距离：0.004845182953560029
# 图像 00122.png 的质心到轮廓上点的归一化距离方差：1.4133987856969305e-07
# 图像 00122.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3333837610231958
# 图像 00123.png 的质心到轮廓上点的归一化平均距离：0.00448635826313148
# 图像 00123.png 的质心到轮廓上点的归一化距离方差：1.087171032667685e-07
# 图像 00123.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.321347437929986
# 图像 00124.png 的质心到轮廓上点的归一化平均距离：0.004703508260427945
# 图像 00124.png 的质心到轮廓上点的归一化距离方差：1.363153153329087e-07
# 图像 00124.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.423522927730072
# 图像 00125.png 的质心到轮廓上点的归一化平均距离：0.00503651278979754
# 图像 00125.png 的质心到轮廓上点的归一化距离方差：2.349159466836446e-07
# 图像 00125.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3743685418725533
# 图像 00126.png 的质心到轮廓上点的归一化平均距离：0.004730344580779953
# 图像 00126.png 的质心到轮廓上点的归一化距离方差：1.8044851667530146e-07
# 图像 00126.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.372740889304288
# 图像 00127.png 的质心到轮廓上点的归一化平均距离：0.004644181782063453
# 图像 00127.png 的质心到轮廓上点的归一化距离方差：2.2765435617429008e-07
# 图像 00127.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3665296611918554
# 图像 00128.png 的质心到轮廓上点的归一化平均距离：0.004696549956756312
# 图像 00128.png 的质心到轮廓上点的归一化距离方差：3.759989589997748e-07
# 图像 00128.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.516342504802596
# 图像 00129.png 的质心到轮廓上点的归一化平均距离：0.005231469662545159
# 图像 00129.png 的质心到轮廓上点的归一化距离方差：4.84459763255167e-07
# 图像 00129.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.567531257971914
# 图像 00130.png 的质心到轮廓上点的归一化平均距离：0.004993886914605007
# 图像 00130.png 的质心到轮廓上点的归一化距离方差：3.7258344203444466e-07
# 图像 00130.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5540300450322828
# 图像 00131.png 的质心到轮廓上点的归一化平均距离：0.005017056096655665
# 图像 00131.png 的质心到轮廓上点的归一化距离方差：3.412444043604031e-07
# 图像 00131.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4700286333186852
# 图像 00132.png 的质心到轮廓上点的归一化平均距离：0.005120479764448164
# 图像 00132.png 的质心到轮廓上点的归一化距离方差：5.936340668007119e-07
# 图像 00132.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5966532376242828
# 图像 00133.png 的质心到轮廓上点的归一化平均距离：0.006008088063880841
# 图像 00133.png 的质心到轮廓上点的归一化距离方差：4.090587240312382e-07
# 图像 00133.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5914949617899306
# 图像 00134.png 的质心到轮廓上点的归一化平均距离：0.005451317667290711
# 图像 00134.png 的质心到轮廓上点的归一化距离方差：2.2586192929312223e-07
# 图像 00134.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4818112922644207
# 图像 00135.png 的质心到轮廓上点的归一化平均距离：0.005213172060525928
# 图像 00135.png 的质心到轮廓上点的归一化距离方差：2.2349944097438198e-07
# 图像 00135.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4902315326116344
# 图像 00136.png 的质心到轮廓上点的归一化平均距离：0.0051616571994277105
# 图像 00136.png 的质心到轮廓上点的归一化距离方差：2.1471908839011937e-07
# 图像 00136.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4632208685751045
# 图像 00137.png 的质心到轮廓上点的归一化平均距离：0.004925284315085487
# 图像 00137.png 的质心到轮廓上点的归一化距离方差：2.7536273000521767e-07
# 图像 00137.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6374162804466368
# 图像 00139.png 的质心到轮廓上点的归一化平均距离：0.0047942931872462435
# 图像 00139.png 的质心到轮廓上点的归一化距离方差：2.3594381703359098e-07
# 图像 00139.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6979420241685885
# 图像 00141.png 的质心到轮廓上点的归一化平均距离：0.005299266994236618
# 图像 00141.png 的质心到轮廓上点的归一化距离方差：3.6114271880608153e-07
# 图像 00141.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.590735262393583
# 图像 00142.png 的质心到轮廓上点的归一化平均距离：0.005154475000366645
# 图像 00142.png 的质心到轮廓上点的归一化距离方差：1.9888580196558875e-07
# 图像 00142.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4317257599996376
# 图像 00143.png 的质心到轮廓上点的归一化平均距离：0.005933737849013451
# 图像 00143.png 的质心到轮廓上点的归一化距离方差：3.200547557914802e-07
# 图像 00143.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.449513776514474
# 图像 00144.png 的质心到轮廓上点的归一化平均距离：0.006115852797326466
# 图像 00144.png 的质心到轮廓上点的归一化距离方差：3.9921458170278655e-07
# 图像 00144.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5006252605523738
# 图像 00145.png 的质心到轮廓上点的归一化平均距离：0.0059668738234771885
# 图像 00145.png 的质心到轮廓上点的归一化距离方差：4.169491244429168e-07
# 图像 00145.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5363580440782547
# 图像 00146.png 的质心到轮廓上点的归一化平均距离：0.005459970468597387
# 图像 00146.png 的质心到轮廓上点的归一化距离方差：4.918526064843985e-07
# 图像 00146.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.529771769230951
# 图像 00147.png 的质心到轮廓上点的归一化平均距离：0.006136818206951005
# 图像 00147.png 的质心到轮廓上点的归一化距离方差：3.5386259764042077e-07
# 图像 00147.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6214646743934293
# 图像 00149.png 的质心到轮廓上点的归一化平均距离：0.005470565809465416
# 图像 00149.png 的质心到轮廓上点的归一化距离方差：2.819996779522496e-07
# 图像 00149.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5012061163710952
# 图像 00150.png 的质心到轮廓上点的归一化平均距离：0.006912851910738861
# 图像 00150.png 的质心到轮廓上点的归一化距离方差：6.946583156117092e-07
# 图像 00150.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6288178398021893
# 图像 00301.png 的质心到轮廓上点的归一化平均距离：0.006107006188258114
# 图像 00301.png 的质心到轮廓上点的归一化距离方差：2.4345254766294045e-07
# 图像 00301.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4326810905767333
# 图像 00302.png 的质心到轮廓上点的归一化平均距离：0.005710930902767401
# 图像 00302.png 的质心到轮廓上点的归一化距离方差：2.158310489646722e-07
# 图像 00302.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3641383655678876
# 图像 00311.png 的质心到轮廓上点的归一化平均距离：0.00572673547461307
# 图像 00311.png 的质心到轮廓上点的归一化距离方差：9.354579974060252e-08
# 图像 00311.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2639232629018393
# 图像 00312.png 的质心到轮廓上点的归一化平均距离：0.005652564001140342
# 图像 00312.png 的质心到轮廓上点的归一化距离方差：1.0307281445603137e-07
# 图像 00312.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.256005979447615
# 图像 00313.png 的质心到轮廓上点的归一化平均距离：0.00605531726376423
# 图像 00313.png 的质心到轮廓上点的归一化距离方差：7.246695407311057e-08
# 图像 00313.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2106384737910798
# 图像 00314.png 的质心到轮廓上点的归一化平均距离：0.005825192837778563
# 图像 00314.png 的质心到轮廓上点的归一化距离方差：4.6597127691107e-08
# 图像 00314.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.1870076042517204
# 图像 00315.png 的质心到轮廓上点的归一化平均距离：0.005689819438627335
# 图像 00315.png 的质心到轮廓上点的归一化距离方差：7.048680973200635e-08
# 图像 00315.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.212363802814129
# 图像 00316.png 的质心到轮廓上点的归一化平均距离：0.005949333783230092
# 图像 00316.png 的质心到轮廓上点的归一化距离方差：6.896607090447024e-08
# 图像 00316.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2608152808456095
# 图像 00317.png 的质心到轮廓上点的归一化平均距离：0.005674517823015288
# 图像 00317.png 的质心到轮廓上点的归一化距离方差：6.402452182211635e-08
# 图像 00317.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2395154163756699
# 图像 00318.png 的质心到轮廓上点的归一化平均距离：0.005493821702864915
# 图像 00318.png 的质心到轮廓上点的归一化距离方差：6.006853828656296e-08
# 图像 00318.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2022759342581542
# 图像 00319.png 的质心到轮廓上点的归一化平均距离：0.006145756676105647
# 图像 00319.png 的质心到轮廓上点的归一化距离方差：1.2832633586734605e-07
# 图像 00319.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3040823447030225
# 图像 00320.png 的质心到轮廓上点的归一化平均距离：0.0057865837736557485
# 图像 00320.png 的质心到轮廓上点的归一化距离方差：1.2607172425939804e-07
# 图像 00320.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.241352625548575
# 图像 00321.png 的质心到轮廓上点的归一化平均距离：0.005282412920790567
# 图像 00321.png 的质心到轮廓上点的归一化距离方差：7.098234659197472e-08
# 图像 00321.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.2001436695605268
# 图像 00322.png 的质心到轮廓上点的归一化平均距离：0.005170700224803224
# 图像 00322.png 的质心到轮廓上点的归一化距离方差：1.1046664866797104e-07
# 图像 00322.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3237908893566745
# 图像 00323.png 的质心到轮廓上点的归一化平均距离：0.006509834710043066
# 图像 00323.png 的质心到轮廓上点的归一化距离方差：4.04034007377817e-07
# 图像 00323.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.395522693696324
# 图像 00324.png 的质心到轮廓上点的归一化平均距离：0.006322879642850169
# 图像 00324.png 的质心到轮廓上点的归一化距离方差：3.526433110186611e-07
# 图像 00324.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.3792438597574628
# 图像 00325.png 的质心到轮廓上点的归一化平均距离：0.0063486191202144
# 图像 00325.png 的质心到轮廓上点的归一化距离方差：4.423247830317259e-07
# 图像 00325.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4201416013981423
# 图像 00326.png 的质心到轮廓上点的归一化平均距离：0.006714106958989632
# 图像 00326.png 的质心到轮廓上点的归一化距离方差：5.281213436102372e-07
# 图像 00326.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.524731669081735
# 图像 00327.png 的质心到轮廓上点的归一化平均距离：0.0061581286684833396
# 图像 00327.png 的质心到轮廓上点的归一化距离方差：8.572935781930889e-07
# 图像 00327.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.856312709989733
# 图像 00328.png 的质心到轮廓上点的归一化平均距离：0.006274956755309827
# 图像 00328.png 的质心到轮廓上点的归一化距离方差：8.136941479677429e-07
# 图像 00328.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7796206922906685
# 图像 00329.png 的质心到轮廓上点的归一化平均距离：0.006182600376334306
# 图像 00329.png 的质心到轮廓上点的归一化距离方差：8.553615194162592e-07
# 图像 00329.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.8203721176836751
# 图像 00330.png 的质心到轮廓上点的归一化平均距离：0.0059409150162965975
# 图像 00330.png 的质心到轮廓上点的归一化距离方差：8.887200342244505e-07
# 图像 00330.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.9143488435810683
# 图像 00331.png 的质心到轮廓上点的归一化平均距离：0.005647984865509661
# 图像 00331.png 的质心到轮廓上点的归一化距离方差：7.106137412863852e-07
# 图像 00331.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7494984954761617
# 图像 00332.png 的质心到轮廓上点的归一化平均距离：0.005905700523544549
# 图像 00332.png 的质心到轮廓上点的归一化距离方差：9.64548286199012e-07
# 图像 00332.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.8071790043482756
# 图像 00333.png 的质心到轮廓上点的归一化平均距离：0.00565970045090941
# 图像 00333.png 的质心到轮廓上点的归一化距离方差：5.527190174442892e-07
# 图像 00333.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.63783393541592
# 图像 00334.png 的质心到轮廓上点的归一化平均距离：0.005617347431860284
# 图像 00334.png 的质心到轮廓上点的归一化距离方差：6.261797810221515e-07
# 图像 00334.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7726144990274004
# 图像 00335.png 的质心到轮廓上点的归一化平均距离：0.005618285040268235
# 图像 00335.png 的质心到轮廓上点的归一化距离方差：6.861500903938848e-07
# 图像 00335.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7906110467026712
# 图像 00336.png 的质心到轮廓上点的归一化平均距离：0.005832584729122815
# 图像 00336.png 的质心到轮廓上点的归一化距离方差：7.136517866048336e-07
# 图像 00336.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5868808263788465
# 图像 00337.png 的质心到轮廓上点的归一化平均距离：0.005257412639585855
# 图像 00337.png 的质心到轮廓上点的归一化距离方差：5.233786467766083e-07
# 图像 00337.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.6975287254078815
# 图像 00338.png 的质心到轮廓上点的归一化平均距离：0.005122340069215994
# 图像 00338.png 的质心到轮廓上点的归一化距离方差：5.711689670205851e-07
# 图像 00338.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7622441905581538
# 图像 00339.png 的质心到轮廓上点的归一化平均距离：0.005336774058830581
# 图像 00339.png 的质心到轮廓上点的归一化距离方差：9.989549416458457e-07
# 图像 00339.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.9366836615712504
# 图像 00340.png 的质心到轮廓上点的归一化平均距离：0.005393316709856233
# 图像 00340.png 的质心到轮廓上点的归一化距离方差：7.773121843847569e-07
# 图像 00340.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7044554964345189
# 图像 00341.png 的质心到轮廓上点的归一化平均距离：0.005059020816702189
# 图像 00341.png 的质心到轮廓上点的归一化距离方差：5.643391856578699e-07
# 图像 00341.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.7020509502383654
# 图像 00342.png 的质心到轮廓上点的归一化平均距离：0.005469835979339455
# 图像 00342.png 的质心到轮廓上点的归一化距离方差：8.745685750841808e-07
# 图像 00342.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.8785850080986648
# 图像 00343.png 的质心到轮廓上点的归一化平均距离：0.005797960396480841
# 图像 00343.png 的质心到轮廓上点的归一化距离方差：1.0014411913136577e-06
# 图像 00343.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：2.046233788200325
# 图像 00344.png 的质心到轮廓上点的归一化平均距离：0.005446755438739455
# 图像 00344.png 的质心到轮廓上点的归一化距离方差：6.733110971284487e-07
# 图像 00344.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.810055407448811
# 图像 00345.png 的质心到轮廓上点的归一化平均距离：0.005699205983364033
# 图像 00345.png 的质心到轮廓上点的归一化距离方差：5.747182243435919e-07
# 图像 00345.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.739211169274588
# 图像 00346.png 的质心到轮廓上点的归一化平均距离：0.005451174492558645
# 图像 00346.png 的质心到轮廓上点的归一化距离方差：3.3671414022443465e-07
# 图像 00346.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.5967549804053554
# 图像 00347.png 的质心到轮廓上点的归一化平均距离：0.005586734282036863
# 图像 00347.png 的质心到轮廓上点的归一化距离方差：2.8875298718269614e-07
# 图像 00347.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.611986352299547
# 图像 00348.png 的质心到轮廓上点的归一化平均距离：0.005580117970062204
# 图像 00348.png 的质心到轮廓上点的归一化距离方差：2.4465544199370676e-07
# 图像 00348.png 的质心到轮廓上点的归一化最大距离与最小距离的比值：1.4401080274286095

# %%
import os
import cv2
import numpy as np

def calculate_pixel_ratio(images_dir, mask_dir):
    # 遍历图像目录中的所有文件
    for filename in os.listdir(images_dir):
        if filename.endswith('.png'):
            try:
                # 读取原始图像
                image_path = os.path.join(images_dir, filename)
                image = cv2.imread(image_path)

                # 转换为灰度图像
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # 读取对应的mask图像
                mask_filename = filename
                mask_path = os.path.join(mask_dir, mask_filename)
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

                if gray_image is None or mask is None:
                    raise Exception(f'无法加载图像或mask: {filename}')

                # 计算图像中的白色像素和mask中的黑色像素
                white_pixels = np.sum(gray_image == 255)
                black_pixels = np.sum(mask == 0)
                # 计算当前图像的比例
                ratio = 1-white_pixels / black_pixels
                print(f"图像 {filename} 中的白色像素与mask中的黑色像素比例: {ratio}")

            except Exception as e:
                print(f'处理 {filename} 时出错: {e}')

# 示例用法
images_dir = r'C:\Users\Administrator\Desktop\mode\test\out5'
mask_dir = r'C:\Users\Administrator\Desktop\mode\test\mask3'
calculate_pixel_ratio(images_dir, mask_dir)
# 计算图像中的白色像素和mask中的黑色像素

# %%
import os
import cv2
import numpy as np
from scipy.spatial import distance

def calculate_density(images_dir, mask_dir):
    # 遍历图像目录中的所有文件
    for filename in os.listdir(images_dir):
        if filename.endswith('.png'):
            try:
                # 读取原始图像
                image_path = os.path.join(images_dir, filename)
                image = cv2.imread(image_path)

                # 转换为灰度图像
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # 读取对应的mask图像
                mask_filename = filename
                mask_path = os.path.join(mask_dir, mask_filename)
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

                if gray_image is None or mask is None:
                    raise Exception(f'无法加载图像或mask: {filename}')

                # 找到mask中的所有黑色点
                black_points = np.where(mask == 0)

                # 计算映射后的黑色点在灰度图像上的坐标
                mapped_points = np.column_stack((black_points[0], black_points[1]))  # 注意坐标顺序
                
                # 打印黑色点的数量
                print("黑色点的数量：", len(mapped_points))
                
                # 在灰度图像范围内找到黑色点
                gray_values = gray_image[mapped_points[:, 0], mapped_points[:, 1]]  # 注意坐标顺序

                # 找到gray_image中的所有黑色点的索引
                black_points_indices = np.where(gray_values == 0)[0]  

                # 使用索引获取对应的坐标
                black_points_coords = mapped_points[black_points_indices]  
                print("黑色点坐标数量：", len(black_points_coords))
                
                
                # 计算黑色点之间的距离
                distances = distance.pdist(black_points_coords)

                # 检查距离是否为空
                if len(distances) > 0:
                    # 计算平均紧密度
                    avg_density = 1 / np.mean(distances)
                    print(f"图像 {filename} 的马尾神经内部黑色点的平均紧密度: {avg_density}")
                else:
                    print(f"图像 {filename} 中没有黑色点。")

            except Exception as e:
                print(f'处理 {filename} 时出错: {e}')

# 示例用法
images_dir = r'C:\Users\Administrator\Desktop\mode\test\out5'
mask_dir = r'C:\Users\Administrator\Desktop\mode\test\mask3'
calculate_density(images_dir, mask_dir)
# 计算平均紧密度

# %%
import os
import cv2
import numpy as np

def find_centroid(points):
    # 计算质心（坐标的均值）
    centroid_x = int(np.mean(points[:, 1]))
    centroid_y = int(np.mean(points[:, 0]))
    return (centroid_y, centroid_x)  # 注意返回的顺序为 (y, x)

def calculate_offsets(images_dir, mask_dir):
    # 存储偏移信息的列表
    offsets = []

    # 遍历图像目录中的所有文件
    for filename in os.listdir(images_dir):
        if filename.endswith('.png'):
            try:
                # 读取原始图像
                image_path = os.path.join(images_dir, filename)
                image = cv2.imread(image_path)
                # 转换为灰度图像
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # 读取对应的mask图像
                mask_filename = filename
                mask_path = os.path.join(mask_dir, mask_filename)
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

                if image is None or mask is None:
                    raise Exception(f'无法加载图像或mask: {filename}')

                # 找到mask中的所有黑色点
                black_points = np.where(mask == 0)

                # 计算映射后的黑色点在灰度图像上的坐标
                mapped_points = np.column_stack((black_points[0], black_points[1]))  # 注意坐标顺序

                # 在灰度图像范围内找到黑色点
                gray_values = gray_image[mapped_points[:, 0], mapped_points[:, 1]]  # 注意坐标顺序

                # 找到gray_image中的所有黑色点的索引
                black_points_indices = np.where(gray_values == 0)[0]
                # 找到gray_image中的所有白色点的索引
                white_points_indices = np.where(gray_values == 255)[0]

                # 使用索引获取对应的坐标
                black_points_coords = mapped_points[black_points_indices]
                white_points_coords = mapped_points[white_points_indices]

                # 计算黑色点和白色点的中心坐标
                black_centroid = find_centroid(black_points_coords)
                white_centroid = find_centroid(white_points_coords)

                # 计算横向和纵向的欧氏距离
                x_offset = black_centroid[1] - white_centroid[1]  # 横向偏移
                y_offset = black_centroid[0] - white_centroid[0]  # 纵向偏移

                offsets.append((x_offset, y_offset))

                print(f"{filename} 中所有黑色点的中心坐标：{black_centroid}")
                print(f"{filename} 中所有白色点的中心坐标：{white_centroid}")
                print(f"{filename} 中黑色点相对于白色点的横向偏移：{x_offset}")
                print(f"{filename} 中黑色点相对于白色点的纵向偏移：{y_offset}")

            except Exception as e:
                print(f'处理 {filename} 时出错: {e}')

    # 返回所有偏移信息
    return offsets

# 示例用法
images_dir = r'C:\Users\Administrator\Desktop\mode\test\out5'
mask_dir = r'C:\Users\Administrator\Desktop\mode\test\mask3'
offsets = calculate_offsets(images_dir, mask_dir)

# 打印所有偏移信息
print("所有偏移信息：", offsets)

# %%
import os
import cv2

# 定义路径
path1 = r'C:\Users\Administrator\Desktop\mode\test\mask4'
path2 = r'C:\Users\Administrator\Desktop\mode\test\mask5'
target_path = r'C:\Users\Administrator\Desktop\mode\test\out6'

# 获取每个目录中的PNG文件列表
files1 = [f for f in os.listdir(path1) if f.endswith('.png')]
files2 = [f for f in os.listdir(path2) if f.endswith('.png')]

# 定义函数：反转图像颜色
def invert_image(image):
    return cv2.bitwise_not(image)

# 定义函数：识别轮廓并绘制
def draw_contours(image):
    # 转换为灰度图像
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # 查找轮廓
    contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 定义颜色列表
    colors = [(0, 255, 0), (255, 0, 0)]  # 两种不同的颜色

    # 绘制轮廓
    for i, contour in enumerate(contours):
        cv2.drawContours(image, [contour], -1, colors[i % len(colors)], 2)

# 遍历path1中的文件
for file in files1:
    if file in files2:  # 检查path2中是否有相应文件
        # 打开两个图像
        img1 = cv2.imread(os.path.join(path1, file))
        img2 = cv2.imread(os.path.join(path2, file))

        # 反转颜色
        inverted_img1 = invert_image(img1)
        inverted_img2 = invert_image(img2)

        # 合并反转后的mask
        merged_mask = cv2.addWeighted(inverted_img1, 1, inverted_img2, 1, 0)

        # 识别轮廓并绘制
        draw_contours(merged_mask)

        # 保存拼接后的mask
        cv2.imwrite(os.path.join(target_path, '' + file), merged_mask)

# %%
import os
import cv2
import numpy as np

# 定义路径
path1 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\intervertebral disc'
path2 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\Facet Joint'
target_path = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\out'

# 获取每个目录中的PNG文件列表
files1 = [f for f in os.listdir(path1) if f.endswith('.png')]
files2 = [f for f in os.listdir(path2) if f.endswith('.png')]

# 定义函数：反转图像颜色
def invert_image(image):
    return cv2.bitwise_not(image)

# 定义函数：识别轮廓并绘制
def draw_contours(image, color_index=0):
    # 转换为灰度图像
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # 查找轮廓
    contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 定义颜色列表
    colors = [(0, 255, 0), (255, 0, 0)]  # 两种不同的颜色

    # 绘制轮廓
    for i, contour in enumerate(contours):
        cv2.drawContours(image, [contour], -1, colors[(color_index + i) % len(colors)], 2)

    return contours  # 返回轮廓变量

def divide_contour_points(contour_points):
    # 根据x坐标排序轮廓点
    sorted_points = sorted(contour_points, key=lambda x: x[0])

    # 计算中点
    midpoint = (sorted_points[0][0] + sorted_points[-1][0]) // 2

    # 根据中点将轮廓点分为左右两组
    left_group = [point for point in sorted_points if point[0] <= midpoint]
    right_group = [point for point in sorted_points if point[0] > midpoint]

    return left_group, right_group

# 遍历path1中的文件
for file in files1:
    if file in files2:  # 检查path2中是否有相应文件
        # 打开两个图像
        img1 = cv2.imread(os.path.join(path1, file))
        img2 = cv2.imread(os.path.join(path2, file))

        # 反转颜色并识别轮廓
        inverted_img1 = invert_image(img1)
        inverted_img2 = invert_image(img2)

        # 绘制第一个图像的轮廓（使用第一种颜色）
        contours1 = draw_contours(inverted_img1, color_index=0)
        # 绘制第二个图像的轮廓（使用第二种颜色）
        contours2 = draw_contours(inverted_img2, color_index=len(contours1))

        # 提取轮廓的坐标点并分成两组（左右）
        contour_points1 = []
        contour_points2 = []
        for contour in contours1:
            for point in contour:
                contour_points1.append(point[0])
        for contour in contours2:
            for point in contour:
                contour_points2.append(point[0])

        # 分割轮廓点为左右两组
        left_group1, right_group1 = divide_contour_points(contour_points1)
        left_group2, right_group2 = divide_contour_points(contour_points2)

        # 比较左边上下轮廓的最近距离点对
        min_distance_upper_left = np.inf
        closest_points_upper_left = []
        for point1 in left_group1:
            for point2 in left_group2:
                distance = np.linalg.norm(np.array(point1) - np.array(point2))
                if distance < min_distance_upper_left:
                    min_distance_upper_left = distance
                    closest_points_upper_left = [point1, point2]

        min_distance_lower_left = np.inf
        closest_points_lower_left = []
        for point1 in right_group1:
            for point2 in right_group2:
                distance = np.linalg.norm(np.array(point1) - np.array(point2))
                if distance < min_distance_lower_left:
                    min_distance_lower_left = distance
                    closest_points_lower_left = [point1, point2]

        # 绘制连接线
        cv2.line(inverted_img1, tuple(closest_points_upper_left[0]), tuple(closest_points_upper_left[1]), (0, 0, 255), 2)
        cv2.line(inverted_img1, tuple(closest_points_lower_left[0]), tuple(closest_points_lower_left[1]), (0, 0, 255), 2)

        # 合并反转后的mask
        merged_mask = cv2.addWeighted(inverted_img1, 1, inverted_img2, 1, 0)

        # 保存拼接后的mask
        cv2.imwrite(os.path.join(target_path, '' + file), merged_mask)
        
                    
 # 画椎间盘和小关节，将轮廓点和关键点标记

# %%
from collections import namedtuple
# 获取每个目录中的PNG文件列表
files1 = [f for f in os.listdir(path1) if f.endswith('.png')]
files2 = [f for f in os.listdir(path2) if f.endswith('.png')]

# 定义函数：反转图像颜色
def invert_image(image):
    return cv2.bitwise_not(image)

# 定义函数：识别轮廓并绘制
def draw_contours(image, color_index=0):
    # 转换为灰度图像
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # 查找轮廓
    contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 定义颜色列表
    colors = [(0, 255, 0), (255, 0, 0)]  # 两种不同的颜色

    # 绘制轮廓
    for i, contour in enumerate(contours):
        cv2.drawContours(image, [contour], -1, colors[(color_index + i) % len(colors)], 2)

    return contours

def divide_contour_points(contour_points):
    # 根据x坐标排序轮廓点
    sorted_points = sorted(contour_points, key=lambda x: x[0])

    # 计算中点
    midpoint = (sorted_points[0][0] + sorted_points[-1][0]) // 2

    # 根据中点将轮廓点分为左右两组
    left_group = [point for point in sorted_points if point[0] <= midpoint]
    right_group = [point for point in sorted_points if point[0] > midpoint]

    return left_group, right_group

def process_masks(img1, img2):
    points = namedtuple('Points', ['d1', 'f1', 'd2', 'f2'])
    contours1 = []
    contours2 = []

    # 反转颜色并识别轮廓
    inverted_img1 = invert_image(img1)
    inverted_img2 = invert_image(img2)

    # 绘制第一个图像的轮廓（使用第一种颜色）
    contours1 = draw_contours(inverted_img1, color_index=0)

    # 绘制第二个图像的轮廓（使用第二种颜色）
    contours2 = draw_contours(inverted_img2, color_index=len(contours1))

    # 提取轮廓的坐标点并分成两组（左右）
    contour_points1 = [point[0] for contour in contours1 for point in contour]
    contour_points2 = [point[0] for contour in contours2 for point in contour]

    # 分割轮廓点为左右两组
    left_group1, right_group1 = divide_contour_points(contour_points1)
    left_group2, right_group2 = divide_contour_points(contour_points2)

    # 查找最接近的点对
    def find_closest_points(group1, group2):
        min_distance = np.inf
        closest_points = []
        for point1 in group1:
            for point2 in group2:
                distance = np.linalg.norm(np.array(point1) - np.array(point2))
                if distance < min_distance:
                    min_distance = distance
                    closest_points = [point1, point2]
        return closest_points

    closest_points_upper_left = find_closest_points(left_group1, left_group2)
    closest_points_lower_left = find_closest_points(right_group1, right_group2)

    return points(
        d1=closest_points_upper_left[0],
        f1=closest_points_upper_left[1],
        d2=closest_points_lower_left[0],
        f2=closest_points_lower_left[1]
    ), contours1, contours2

# 在主程序中调用处理函数
result, contours1, contours2 = process_masks(img1, img2)

# 打印结果中的数值
print("最上方左边点的坐标：", result.d1)
print("最上方右边点的坐标：", result.f1)
print("最下方左边点的坐标：", result.d2)
print("最下方右边点的坐标：", result.f2)
# 这是一个打包的函数，返回contours1, contours2和在主程序中调用处理函数
# Out:
# 最上方左边点的坐标： [209 242]
# 最上方右边点的坐标： [210 251]
# 最下方左边点的坐标： [276 240]
# 最下方右边点的坐标： [271 248]

# %%
import os
import numpy as np
import cv2

path1 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\intervertebral disc'
path2 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\Facet Joint'


# 获取每个目录中的PNG文件列表
files1 = [f for f in os.listdir(path1) if f.endswith('.png')]
files2 = [f for f in os.listdir(path2) if f.endswith('.png')]


# 在主程序中调用处理函数
for file in files1:
    if file in files2:  # 检查path2中是否有相应文件
        # 打开两个图像
        img1 = cv2.imread(os.path.join(path1, file))
        img2 = cv2.imread(os.path.join(path2, file))

        # 调用处理函数并获取结果
        result, contours1, contours2 = process_masks(img1, img2)


        # 创建一个空列表来存储展开后的轮廓
        expanded_contours_1 = []
        expanded_contours_2 = []
        
        # 将每个轮廓的点展开成二维数组并存储到新列表中
        for contour in contours1:
            expanded_contour_1 = contour.reshape(-1, 2)
            expanded_contours_1.append(expanded_contour_1)
        for contour in contours2:
            expanded_contour_2 = contour.reshape(-1, 2)
            expanded_contours_2.append(expanded_contour_2)
            
        # 将展开后的轮廓列表合并成一个二维数组
        contours1_array = np.concatenate(expanded_contours_1)
        contours2_array = np.concatenate(expanded_contours_2)
        
        d1=result.d1
        d2=result.d2
        f1=result.f1
        f2=result.f2
        print("f2：",f2)
        # 寻找d1在contours1中的索引
        d1_index = np.where((contours1_array[:, 0] == d1[0]) & (contours1_array[:, 1] == d1[1]))[0]
        d2_index = np.where((contours1_array[:, 0] == d2[0]) & (contours1_array[:, 1] == d2[1]))[0]

        D1 = []
        D1.append(contours1_array[d1_index[0]:d2_index[0]+1])    
        
        # 寻找f1在contours2中的索引
        f1_index = np.where((contours2_array[:, 0] == f1[0]) & (contours2_array[:, 1] == f1[1]))[0]
        f2_index = np.where((contours2_array[:, 0] == f2[0]) & (contours2_array[:, 1] == f2[1]))[0]
        print("f1_index：",f1_index)
        print("f2_index：",f2_index)
        
        F1 = []
        if f2_index[0] > f1_index[0]:      
            if f1_index[0] < 1:
                F1.append(contours2_array[f2_index[0]:])              
            else:    
                F1.append(contours2_array[:f1_index[0]])
        else:
            F1.append(contours2_array[f2_index[0]:f1_index[0]+1])    
            
        for contour1 in D1:
            contour1 = np.array(contour1)
        for contour2 in F1:
            contour2 = np.array(contour2)    
        print(f'contour2 元素数: {contour2.size}')
       
        combined_array = np.concatenate((contour1, contour2), axis=0)
            
        
        # 创建一个白色背景图像
        background = np.ones((512, 512, 3), dtype=np.uint8) * 255


        
        # 绘制contours1（蓝色）
        cv2.drawContours(background, contours1, -1, (255, 0, 0), thickness=1)

        # 绘制contours2（红色）
        cv2.drawContours(background, contours2, -1, (0, 0, 255), thickness=1)
        
        # 绘制椎管区域（黄色）
        cv2.drawContours(background, [np.array(combined_array)], -1, (0, 255, 255), thickness=1)
            
        # 计算面积
        area = cv2.contourArea(np.array(combined_array))
        print("椎管封闭面积为:", area)   
        # 显示图像轮廓
        cv2.imshow('Contours', background)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
# Out:
# f2： [285 280]
# f1_index： [54]
# f2_index： [0]
# contour2 元素数: 110
# 椎管封闭面积为: 2594.0
# f2： [273 274]
# f1_index： [45]
# f2_index： [4]
# contour2 元素数: 84
# 椎管封闭面积为: 2038.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2072\4293031036.py in <module>
#      94         # 显示图像轮廓
#      95         cv2.imshow('Contours', background)
# ---> 96         cv2.waitKey(0)
#      97         cv2.destroyAllWindows()
#      98
#
# KeyboardInterrupt:

# %%
import numpy as np
import cv2
import os

path1 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\intervertebral disc'
path2 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\Facet Joint'


# 获取每个目录中的PNG文件列表
files1 = [f for f in os.listdir(path1) if f.endswith('.png')]
files2 = [f for f in os.listdir(path2) if f.endswith('.png')]


for file in files1:
    if file in files2:  # 检查path2中是否有相应文件
        # 打开两个图像
        img1 = cv2.imread(os.path.join(path1, file))
        img2 = cv2.imread(os.path.join(path2, file))

        # 调用处理函数并获取结果
        result, contours1, contours2 = process_masks(img1, img2)

        # 创建一个空列表来存储展开后的轮廓
        expanded_contours = []

        # 将每个轮廓的点展开成二维数组并存储到新列表中
        for contour in contours1:
            expanded_contour = contour.reshape(-1, 2)
            expanded_contours.append(expanded_contour)

        # 将展开后的轮廓列表合并成一个二维数组
        contours1_array = np.concatenate(expanded_contours)

        d1 = result.d1
        d2 = result.d2

        # 寻找d1在contours1中的索引
        d1_index = np.where((contours1_array[:, 0] == d1[0]) & (contours1_array[:, 1] == d1[1]))[0]
        d2_index = np.where((contours1_array[:, 0] == d2[0]) & (contours1_array[:, 1] == d2[1]))[0]

        D1 = []
        D1.append(contours1_array[d1_index[0]:d2_index[0] + 1])

        # 连接d1和d2，并将直线上的所有点存入d1_d2数组内部
        d1_d2 = []

        # 计算直线上的所有点
        delta_x = d2[0] - d1[0]
        delta_y = d2[1] - d1[1]
        distance = max(abs(delta_x), abs(delta_y))  # 计算直线的长度
        steps = max(distance, 1) + 1  # 确保至少包含两个端点
        for i in range(steps):
            x = int(d1[0] + i * delta_x / distance)
            y = int(d1[1] + i * delta_y / distance)
            d1_d2.append((x, y))

        for contour in D1:
            contour = np.array(contour)
            # 将d1_d2列表转换为NumPy数组，每个点对作为数组的一行
            d1_d2_array = np.array(d1_d2)
            combined_array = np.concatenate((contour, d1_d2_array), axis=0)

            # 创建一个空白图像作为背景
            background = np.ones((512, 512, 3), dtype=np.uint8) * 255  # 创建白色背景图像，三通道

            # 绘制contours1（蓝色）
            cv2.drawContours(background, contours1, -1, (255, 0, 0), thickness=1)

            # 绘制contours2（红色）
            cv2.drawContours(background, contours2, -1, (0, 0, 255), thickness=1)
            
            # 绘制contour（黄色）
            cv2.drawContours(background, [np.array(combined_array)], -1, (0, 255, 255), thickness=1)
            
            # 绘制contour（浅蓝色）
            cv2.drawContours(background, [np.array(d1_d2_array)], -1, (255, 255, 0), thickness=1)
            
            # 计算面积
            area = cv2.contourArea(np.array(combined_array))

            # 计算d1和d2的y轴均值
            d1_y_mean = np.mean(d1[1])
            d2_y_mean = np.mean(d2[1])

            # 计算D1的y轴均值
            D1_y_mean = np.mean(np.concatenate(D1)[:, 1])

            # 比较均值并调整面积
            if D1_y_mean < (d1_y_mean + d2_y_mean) / 2:
                area = -area

            print("封闭面积为:", area)

            # 显示结果
            cv2.imshow('Result', background)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
# Out:
# 封闭面积为: -344.0
# 封闭面积为: -142.0
# 封闭面积为: -171.0
# 封闭面积为: -173.0
# 封闭面积为: 53.0
# 封闭面积为: 83.0
# 封闭面积为: 135.0
# 封闭面积为: 252.0
# 封闭面积为: 328.0
# 封闭面积为: 293.0
# 封闭面积为: 457.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2072\2133274869.py in <module>
#      94             # 显示结果
#      95             cv2.imshow('Result', background)
# ---> 96             cv2.waitKey(0)
#      97             cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import cv2
import math

path1 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\intervertebral disc'
path2 = r'C:\Users\Administrator\Desktop\mode\segement\Figure-data\masks\Facet Joint'


# 获取每个目录中的PNG文件列表
files1 = [f for f in os.listdir(path1) if f.endswith('.png')]
files2 = [f for f in os.listdir(path2) if f.endswith('.png')]

def calculate_intersection_points(G, f3, contours1_array):
    # 将f3的格式转换为元组
    f3 = (f3[0], f3[1])

    # 计算直线上的所有点
    delta_x = G[0] - f3[0]
    delta_y = G[1] - f3[1]
    distance = max(abs(delta_x), abs(delta_y))  # 计算直线的长度
    steps = max(distance, 1) + 1  # 确保至少包含两个端点
    f3_G = []
    for i in range(steps):
        x = int(f3[0] + i * delta_x / distance)
        y = int(f3[1] + i * delta_y / distance)
        f3_G.append((x, y))
        
    
    closest_point = None
    min_distance = float('inf')
    for point2 in f3_G:
        for point1 in contours1_array:
            # 计算两点之间的距离
            distance = math.sqrt((point2[0] - point1[0])**2 + (point2[1] - point1[1])**2)
            # 如果找到更接近的点，则更新最小距离和最接近的点坐标
            if distance < min_distance:
                min_distance = distance
                closest_point = point2     
                
    return closest_point




# 在主程序中调用处理函数
for file in files1:
    if file in files2:  # 检查path2中是否有相应文件
        # 打开两个图像
        img1 = cv2.imread(os.path.join(path1, file))
        img2 = cv2.imread(os.path.join(path2, file))

        # 调用处理函数并获取结果
        result, contours1, contours2 = process_masks(img1, img2)


        # 创建一个空列表来存储展开后的轮廓
        expanded_contours_1 = []
        expanded_contours_2 = []
        
        # 将每个轮廓的点展开成二维数组并存储到新列表中
        for contour in contours1:
            expanded_contour_1 = contour.reshape(-1, 2)
            expanded_contours_1.append(expanded_contour_1)
        for contour in contours2:
            expanded_contour_2 = contour.reshape(-1, 2)
            expanded_contours_2.append(expanded_contour_2)
            
        # 将展开后的轮廓列表合并成一个二维数组
        contours1_array = np.concatenate(expanded_contours_1)
        contours2_array = np.concatenate(expanded_contours_2)
        
        d1=result.d1
        d2=result.d2
        f1=result.f1
        f2=result.f2

        # 寻找d1在contours1中的索引
        d1_index = np.where((contours1_array[:, 0] == d1[0]) & (contours1_array[:, 1] == d1[1]))[0]
        d2_index = np.where((contours1_array[:, 0] == d2[0]) & (contours1_array[:, 1] == d2[1]))[0]

        D1 = []
        D1.append(contours1_array[d1_index[0]:d2_index[0]+1])    
        
        # 寻找d1在contours1中的索引
        f1_index = np.where((contours2_array[:, 0] == f1[0]) & (contours2_array[:, 1] == f1[1]))[0]
        f2_index = np.where((contours2_array[:, 0] == f2[0]) & (contours2_array[:, 1] == f2[1]))[0]

        F1 = []
        if f2_index[0] > f1_index[0]:      
            if f1_index[0] < 1:
                F1.append(contours2_array[f2_index[0]:])              
            else:    
                F1.append(contours2_array[:f1_index[0]])
        else:
            F1.append(contours2_array[f2_index[0]:f1_index[0]+1])        
        
                      
        for contour1 in D1:
            contour1 = np.array(contour1)
        for contour2 in F1:
            contour2 = np.array(contour2)    
            
        # 找到F1中最低的点f3
        f3 = F1[0][np.argmax(F1[0][:, 1])]

        # 计算contours1的质心G
        M = cv2.moments(contours1_array)
        G = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
        
        
        # 调用函数
        closest_point = calculate_intersection_points(G, f3, contours1_array)

        print("交点坐标:", closest_point)
        distance = math.sqrt((closest_point[0] - f3[0])**2 + (closest_point[1] - f3[1])**2)
        print("失状径:", distance)
        
        # 在相同的画布上连接f3和G并显示
        # 创建一个空白图像作为背景
        background = np.ones((512, 512, 3), dtype=np.uint8) * 255  # 创建白色背景图像，三通道
        
        # 绘制contours1（蓝色）
        cv2.drawContours(background, contours1, -1, (255, 0, 0), thickness=1)

        # 绘制contours2（红色）
        cv2.drawContours(background, contours2, -1, (0, 0, 255), thickness=1)
        
        cv2.circle(background, (closest_point[0], closest_point[1]), 5, (255, 255, 0), -1)  # 在交点处绘制一个圆点
        cv2.circle(background, (f3[0], f3[1]), 5, (0, 255, 0), -1)  # 在f3处绘制一个绿色圆点
        cv2.circle(background, (G[0], G[1]), 5, (0, 0, 255), -1)  # 在G处绘制一个红色圆点
        cv2.line(background, (f3[0], f3[1]), (G[0], G[1]), (255, 255, 0), 1)  # 连接f3和G

        # 显示结果
        cv2.imshow("Result", background)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
# Out:
# 交点坐标: (249, 247)
# 失状径: 66.27216610312357
# 交点坐标: (246, 249)
# 失状径: 57.42821606144492
# 交点坐标: (247, 250)
# 失状径: 54.230987451824994
# 交点坐标: (246, 256)
# 失状径: 42.42640687119285
# 交点坐标: (248, 255)
# 失状径: 42.42640687119285
# 交点坐标: (250, 243)
# 失状径: 35.6931365951495
# 交点坐标: (248, 251)
# 失状径: 36.124783736376884
# 交点坐标: (246, 248)
# 失状径: 32.0624390837628
# 交点坐标: (250, 253)
# 失状径: 28.160255680657446
# 交点坐标: (247, 247)
# 失状径: 31.400636936215164
# 交点坐标: (247, 254)
# 失状径: 29.427877939124322
# 交点坐标: (243, 245)
# 失状径: 40.11234224026316
# 交点坐标: (248, 262)
# 失状径: 56.00892785976178
# 交点坐标: (248, 261)
# 失状径: 55.00909015790027
# 交点坐标: (247, 262)
# 失状径: 65.0
# 交点坐标: (251, 274)
# 失状径: 44.04543109109048
# 交点坐标: (249, 274)
# 失状径: 60.07495318350236
# 交点坐标: (249, 273)
# 失状径: 52.03844732503075
# 交点坐标: (253, 277)
# 失状径: 42.0
# 交点坐标: (253, 282)
# 失状径: 43.104524124504614
# 交点坐标: (242, 281)
# 失状径: 50.96076922496363
# 交点坐标: (259, 280)
# 失状径: 44.10215414239989
# 交点坐标: (258, 281)
# 失状径: 30.01666203960727
# 交点坐标: (259, 280)
# 失状径: 28.071337695236398
# 交点坐标: (260, 286)
# 失状径: 43.18564576337837
# 交点坐标: (260, 290)
# 失状径: 31.144823004794873
# 交点坐标: (259, 288)
# 失状径: 34.058772731852805
# 交点坐标: (257, 286)
# 失状径: 40.049968789001575
# 交点坐标: (259, 261)
# 失状径: 45.044422518220834
# 交点坐标: (260, 257)
# 失状径: 44.0
# 交点坐标: (255, 268)
# 失状径: 40.0
# 交点坐标: (255, 268)
# 失状径: 38.0
# 交点坐标: (250, 260)
# 失状径: 36.0
# 交点坐标: (253, 264)
# 失状径: 31.016124838541646
# 交点坐标: (253, 264)
# 失状径: 32.01562118716424
# 交点坐标: (251, 261)
# 失状径: 33.0
# 交点坐标: (248, 259)
# 失状径: 31.064449134018133
# 交点坐标: (250, 267)
# 失状径: 23.0
# 交点坐标: (249, 263)
# 失状径: 29.017236257093817
# 交点坐标: (249, 256)
# 失状径: 36.013886210738214
# 交点坐标: (275, 260)
# 失状径: 54.0
# 交点坐标: (262, 261)
# 失状径: 49.040799340956916
# 交点坐标: (258, 266)
# 失状径: 48.010415536631214
# 交点坐标: (256, 260)
# 失状径: 44.04543109109048
# 交点坐标: (257, 263)
# 失状径: 44.04543109109048
# 交点坐标: (257, 271)
# 失状径: 35.05709628591621
# 交点坐标: (256, 272)
# 失状径: 33.06055050963308
# 交点坐标: (254, 273)
# 失状径: 33.06055050963308
# 交点坐标: (254, 267)
# 失状径: 43.04648650006177
# 交点坐标: (254, 262)
# 失状径: 41.012193308819754
# 交点坐标: (256, 264)
# 失状径: 33.54101966249684
# 交点坐标: (258, 262)
# 失状径: 36.6742416417845
# 交点坐标: (254, 263)
# 失状径: 39.319206502675
# 交点坐标: (252, 265)
# 失状径: 42.1070065428546
# 交点坐标: (259, 289)
# 失状径: 49.040799340956916
# 交点坐标: (259, 288)
# 失状径: 60.07495318350236
# 交点坐标: (261, 286)
# 失状径: 55.036351623268054
# 交点坐标: (253, 271)
# 失状径: 56.08029957123981
# 交点坐标: (250, 276)
# 失状径: 53.08483775994799
# 交点坐标: (248, 275)
# 失状径: 40.0
# 交点坐标: (250, 268)
# 失状径: 45.044422518220834
# 交点坐标: (251, 266)
# 失状径: 46.04345773288535
# 交点坐标: (252, 269)
# 失状径: 56.0
# 交点坐标: (252, 266)
# 失状径: 48.010415536631214
# 交点坐标: (255, 269)
# 失状径: 35.0
# 交点坐标: (258, 269)
# 失状径: 37.0
# 交点坐标: (260, 279)
# 失状径: 29.0
# 交点坐标: (261, 275)
# 失状径: 37.05401462729781
# 交点坐标: (264, 280)
# 失状径: 14.0
# 交点坐标: (268, 277)
# 失状径: 22.02271554554524
# 交点坐标: (271, 258)
# 失状径: 41.10960958218893
# 交点坐标: (268, 252)
# 失状径: 51.03920062069938
# 交点坐标: (271, 251)
# 失状径: 55.57877292636101
# 交点坐标: (258, 251)
# 失状径: 53.009433122794285
# 交点坐标: (255, 250)
# 失状径: 62.03224967708329
# 交点坐标: (258, 250)
# 失状径: 52.23983154643591
# 交点坐标: (260, 252)
# 失状径: 54.147945482723536
# 交点坐标: (261, 249)
# 失状径: 58.309518948453004
# 交点坐标: (263, 248)
# 失状径: 42.01190307520001
# 交点坐标: (264, 248)
# 失状径: 48.25971404805462
# 交点坐标: (262, 248)
# 失状径: 51.03920062069938
# 交点坐标: (262, 247)
# 失状径: 48.16637831516918
# 交点坐标: (264, 247)
# 失状径: 42.1070065428546
# 交点坐标: (265, 256)
# 失状径: 38.05259518088089
# 交点坐标: (264, 253)
# 失状径: 39.01281840626232
# 交点坐标: (265, 252)
# 失状径: 39.01281840626232
# 交点坐标: (264, 243)
# 失状径: 35.22782990761707
# 交点坐标: (263, 251)
# 失状径: 23.194827009486403
# 交点坐标: (258, 239)
# 失状径: 47.095647357266465
# 交点坐标: (254, 261)
# 失状径: 46.0
# 交点坐标: (252, 251)
# 失状径: 46.0
# 交点坐标: (248, 248)
# 失状径: 54.0
# 交点坐标: (247, 256)
# 失状径: 42.1070065428546
# 交点坐标: (247, 257)
# 失状径: 45.044422518220834
# 交点坐标: (247, 255)
# 失状径: 47.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2072\315392210.py in <module>
#     134         # 显示结果
#     135         cv2.imshow("Result", background)
# --> 136         cv2.waitKey(0)
#     137         cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
from PIL import Image

# 打开图1
image1 = Image.open("C:\\Users\\Administrator\\Desktop\\mode\\test\\test3\\1.png")

# 打开图2
image2 = Image.open("C:\\Users\\Administrator\\Desktop\\mode\\test\\test3\\00105_mask.png")

# 将图2转换为RGBA模式（如果尚未）
# image2 = image2.convert("RGBA")

# 获取图2的大小
width, height = image2.size

# 将图2粘贴到图1上，只有在图2上的像素不是完全黑色或白色时才贴上
for x in range(width):
    for y in range(height):
        pixel = image2.getpixel((x, y))
        # 如果像素不是完全黑色或白色，则将其粘贴到图1上
#         if pixel[0] != 0 or pixel[1] != 0 or pixel[2] != 0:
        image1.putpixel((x, y), pixel)

# 保存结果到路径3
image1.save("C:\\Users\\Administrator\\Desktop\\mode\\test\\test3\\00001_output.png")
